# %%
# imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from functools import reduce
from sklearn.linear_model import Lasso, LogisticRegression, LassoCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, 
    mean_squared_error, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report, 
    roc_curve, 
    roc_auc_score
)
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# load all coefficient dfs
coefficient_df_2018 = pd.read_csv('coefficient_df_2018_derived.csv')
coefficient_df_2019 = pd.read_csv('coefficient_df_2019_derived.csv')
coefficient_df_2020 = pd.read_csv('coefficient_df_2020_derived.csv')
coefficient_df_2021 = pd.read_csv('coefficient_df_2021_derived.csv')
coefficient_df_2022 = pd.read_csv('coefficient_df_2022_derived.csv')

# %%
# function that deletes all of the zero coefficients and sorts it
def deletezero_sort(df):
    df = df[df['Coefficient'] != 0]
    df['abs_coefficient'] = df['Coefficient'].abs()
    df['odds_ratio'] = np.exp(df['Coefficient'])
    df = df.sort_values(by='abs_coefficient', ascending=False)
    return df

# %%
# function that only keeps race, sex, and ethnicity features and sorts it
def filter_features_by_prefix(df):
    prefixes = ['derived_ethnicity', 'derived_race', 'applicant_ethnicity', 'co-applicant_ethnicity', 'applicant_race', 'co-applicant_race']
    filtered_coefficients = pd.DataFrame()
    for prefix in prefixes:
        filtered_coefficients = pd.concat([filtered_coefficients, df[df['Feature'].str.startswith(prefix)]])
    filtered_coefficients['abs_coefficient'] = filtered_coefficients['Coefficient'].abs()
    filtered_coefficients['odds_ratio'] = np.exp(filtered_coefficients['Coefficient'])
    filtered_coefficients = filtered_coefficients.sort_values(by='abs_coefficient', ascending=False)
    return filtered_coefficients

# %% [markdown]
# ## 2018

# %%
coefficient_sorted_2018 = deletezero_sort(coefficient_df_2018)
coefficient_sorted_2018
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.325823
# 40                       purchaser_type_Not applicable    -2.096579
# 51                         hoepa_status_Not applicable    -1.492413
# 50               hoepa_status_Not a high-cost mortgage     1.418875
# 142    initially_payable_to_institution_Not applicable    -0.770397
# ..                                                 ...          ...
# 59   manufactured_home_land_property_interest_Indir...     0.004803
# 44   loan_type_Federal Housing Administration insur...    -0.003963
# 16      derived_loan_product_type_FHA:Subordinate Lien    -0.002784
# 72                             debt_to_income_ratio_42     0.000569
# 98     co-applicant_credit_score_type_VantageScore 2.0     0.000552
#
#      abs_coefficient  odds_ratio
# 0           4.325823   75.627709
# 40          2.096579    0.122876
# 51          1.492413    0.224830
# 50          1.418875    4.132468
# 142         0.770397    0.462829
# ..               ...         ...
# 59          0.004803    1.004815
# 44          0.003963    0.996045
# 16          0.002784    0.997219
# 72          0.000569    1.000570
# 98          0.000552    1.000552
#
# [76 rows x 4 columns]

# %%
coefficient_imp_2018 = filter_features_by_prefix(coefficient_df_2018)
coefficient_imp_2018
# Out:
#                                                Feature  Coefficient  \
# 21                derived_ethnicity_Hispanic or Latino     0.353435
# 100        applicant_ethnicity_observed_Not applicable    -0.171170
# 105             applicant_race_observed_Not applicable    -0.149867
# 29                     derived_race_Race Not Available    -0.094953
# 25                                  derived_race_Asian    -0.054477
# 22                             derived_ethnicity_Joint    -0.031588
# 24       derived_race_American Indian or Alaska Native    -0.022001
# 101  applicant_ethnicity_observed_Not collected on ...    -0.005822
# 28   derived_race_Native Hawaiian or Other Pacific ...    -0.005088
# 104  co-applicant_ethnicity_observed_Not collected ...     0.000000
# 108          co-applicant_race_observed_Not applicable     0.000000
# 107         co-applicant_race_observed_No co-applicant     0.000000
# 106  applicant_race_observed_Not collected on the b...     0.000000
# 20           derived_ethnicity_Ethnicity Not Available     0.000000
# 103     co-applicant_ethnicity_observed_Not applicable     0.000000
# 102    co-applicant_ethnicity_observed_No co-applicant     0.000000
# 27                                  derived_race_Joint     0.000000
# 26              derived_race_Black or African American     0.000000
# 23               derived_race_2 or more minority races     0.000000
# 109  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  odds_ratio
# 21          0.353435    1.423950
# 100         0.171170    0.842679
# 105         0.149867    0.860822
# 29          0.094953    0.909416
# 25          0.054477    0.946981
# 22          0.031588    0.968906
# 24          0.022001    0.978239
# 101         0.005822    0.994195
# 28          0.005088    0.994925
# 104         0.000000    1.000000
# 108         0.000000    1.000000
# 107         0.000000    1.000000
# 106         0.000000    1.000000
# 20          0.000000    1.000000
# 103         0.000000    1.000000
# 102         0.000000    1.000000
# 27          0.000000    1.000000
# 26          0.000000    1.000000
# 23          0.000000    1.000000
# 109         0.000000    1.000000

# %% [markdown]
# ## 2019

# %%
coefficient_sorted_2019 = deletezero_sort(coefficient_df_2019)
coefficient_sorted_2019
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                              Feature  Coefficient  \
# 0                                              const     4.810212
# 39                     purchaser_type_Not applicable    -2.192418
# 51                       hoepa_status_Not applicable    -1.509426
# 50             hoepa_status_Not a high-cost mortgage     1.402711
# 138  initially_payable_to_institution_Not applicable    -0.828248
# ..                                               ...          ...
# 129                           co-applicant_age_45-54    -0.002910
# 2                                loan_to_value_ratio    -0.002266
# 123                              applicant_age_45-54     0.001999
# 136                       applicant_age_above_62_Yes     0.001667
# 107        co-applicant_race_observed_Not applicable     0.000729
#
#      abs_coefficient  odds_ratio
# 0           4.810212  122.757693
# 39          2.192418    0.111646
# 51          1.509426    0.221037
# 50          1.402711    4.066209
# 138         0.828248    0.436814
# ..               ...         ...
# 129         0.002910    0.997094
# 2           0.002266    0.997737
# 123         0.001999    1.002001
# 136         0.001667    1.001669
# 107         0.000729    1.000729
#
# [117 rows x 4 columns]

# %%
coefficient_imp_2019 = filter_features_by_prefix(coefficient_df_2019)
coefficient_imp_2019
# Out:
#                                                Feature  Coefficient  \
# 21                derived_ethnicity_Hispanic or Latino     0.341552
# 99         applicant_ethnicity_observed_Not applicable    -0.171936
# 104             applicant_race_observed_Not applicable    -0.121263
# 106         co-applicant_race_observed_No co-applicant    -0.072071
# 24       derived_race_American Indian or Alaska Native    -0.064587
# 22                             derived_ethnicity_Joint     0.061885
# 26              derived_race_Black or African American    -0.057667
# 23               derived_race_2 or more minority races    -0.056746
# 27                                  derived_race_Joint    -0.056641
# 29                     derived_race_Race Not Available    -0.056546
# 28   derived_race_Native Hawaiian or Other Pacific ...    -0.043770
# 108  co-applicant_race_observed_Not collected on th...     0.036407
# 25                                  derived_race_Asian    -0.032520
# 20           derived_ethnicity_Ethnicity Not Available     0.031557
# 105  applicant_race_observed_Not collected on the b...     0.020103
# 107          co-applicant_race_observed_Not applicable     0.000729
# 101    co-applicant_ethnicity_observed_No co-applicant     0.000000
# 102     co-applicant_ethnicity_observed_Not applicable     0.000000
# 103  co-applicant_ethnicity_observed_Not collected ...     0.000000
# 100  applicant_ethnicity_observed_Not collected on ...     0.000000
#
#      abs_coefficient  odds_ratio
# 21          0.341552    1.407130
# 99          0.171936    0.842033
# 104         0.121263    0.885801
# 106         0.072071    0.930465
# 24          0.064587    0.937454
# 22          0.061885    1.063840
# 26          0.057667    0.943964
# 23          0.056746    0.944834
# 27          0.056641    0.944933
# 29          0.056546    0.945023
# 28          0.043770    0.957174
# 108         0.036407    1.037078
# 25          0.032520    0.968003
# 20          0.031557    1.032060
# 105         0.020103    1.020306
# 107         0.000729    1.000729
# 101         0.000000    1.000000
# 102         0.000000    1.000000
# 103         0.000000    1.000000
# 100         0.000000    1.000000

# %% [markdown]
# ## 2020

# %%
coefficient_sorted_2020 = deletezero_sort(coefficient_df_2020)
coefficient_sorted_2020
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     5.136895
# 40                       purchaser_type_Not applicable    -1.973887
# 52                         hoepa_status_Not applicable    -1.676307
# 51               hoepa_status_Not a high-cost mortgage     1.496581
# 139    initially_payable_to_institution_Not applicable    -0.779783
# ..                                                 ...          ...
# 18             derived_loan_product_type_VA:First Lien     0.003823
# 61                                       total_units_2    -0.003570
# 54     interest_only_payment_No interest-only payments    -0.003527
# 137                         applicant_age_above_62_Yes     0.002127
# 106  applicant_race_observed_Not collected on the b...    -0.001549
#
#      abs_coefficient  odds_ratio
# 0           5.136895  170.186551
# 40          1.973887    0.138916
# 52          1.676307    0.187064
# 51          1.496581    4.466393
# 139         0.779783    0.458506
# ..               ...         ...
# 18          0.003823    1.003830
# 61          0.003570    0.996436
# 54          0.003527    0.996479
# 137         0.002127    1.002129
# 106         0.001549    0.998453
#
# [136 rows x 4 columns]

# %%
coefficient_imp_2020 = filter_features_by_prefix(coefficient_df_2020)
coefficient_imp_2020
# Out:
#                                                Feature  Coefficient  \
# 29                     derived_race_Race Not Available    -0.437556
# 105             applicant_race_observed_Not applicable    -0.429200
# 21                derived_ethnicity_Hispanic or Latino     0.392756
# 20           derived_ethnicity_Ethnicity Not Available     0.215829
# 100        applicant_ethnicity_observed_Not applicable    -0.210161
# 27                                  derived_race_Joint    -0.155360
# 101  applicant_ethnicity_observed_Not collected on ...    -0.153122
# 104  co-applicant_ethnicity_observed_Not collected ...     0.131913
# 102    co-applicant_ethnicity_observed_No co-applicant     0.053160
# 103     co-applicant_ethnicity_observed_Not applicable     0.052796
# 107         co-applicant_race_observed_No co-applicant     0.052198
# 109  co-applicant_race_observed_Not collected on th...     0.048630
# 26              derived_race_Black or African American    -0.038380
# 22                             derived_ethnicity_Joint     0.023813
# 108          co-applicant_race_observed_Not applicable     0.020497
# 24       derived_race_American Indian or Alaska Native     0.013160
# 23               derived_race_2 or more minority races    -0.012585
# 25                                  derived_race_Asian    -0.011614
# 28   derived_race_Native Hawaiian or Other Pacific ...     0.007093
# 106  applicant_race_observed_Not collected on the b...    -0.001549
#
#      abs_coefficient  odds_ratio
# 29          0.437556    0.645612
# 105         0.429200    0.651030
# 21          0.392756    1.481057
# 20          0.215829    1.240890
# 100         0.210161    0.810454
# 27          0.155360    0.856107
# 101         0.153122    0.858025
# 104         0.131913    1.141010
# 102         0.053160    1.054598
# 103         0.052796    1.054215
# 107         0.052198    1.053584
# 109         0.048630    1.049831
# 26          0.038380    0.962347
# 22          0.023813    1.024099
# 108         0.020497    1.020709
# 24          0.013160    1.013247
# 23          0.012585    0.987494
# 25          0.011614    0.988453
# 28          0.007093    1.007118
# 106         0.001549    0.998453

# %% [markdown]
# ## 2021

# %%
coefficient_sorted_2021 = deletezero_sort(coefficient_df_2021)
coefficient_sorted_2021
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature   Coefficient  \
# 0                                                const  4.164035e+00
# 50                         hoepa_status_Not applicable -1.501168e+00
# 39                       purchaser_type_Not applicable -1.442490e+00
# 49               hoepa_status_Not a high-cost mortgage  1.361813e+00
# 37                           purchaser_type_Ginnie Mae  7.216322e-01
# ..                                                 ...           ...
# 68                             debt_to_income_ratio_41 -2.589312e-03
# 12                   tract_median_age_of_housing_units  2.517540e-03
# 67                             debt_to_income_ratio_40 -1.133521e-03
# 97   co-applicant_credit_score_type_Other credit sc... -1.671755e-06
# 103     co-applicant_ethnicity_observed_Not applicable  1.399248e-09
#
#      abs_coefficient  odds_ratio
# 0       4.164035e+00   64.330558
# 50      1.501168e+00    0.222870
# 39      1.442490e+00    0.236339
# 49      1.361813e+00    3.903262
# 37      7.216322e-01    2.057789
# ..               ...         ...
# 68      2.589312e-03    0.997414
# 12      2.517540e-03    1.002521
# 67      1.133521e-03    0.998867
# 97      1.671755e-06    0.999998
# 103     1.399248e-09    1.000000
#
# [139 rows x 4 columns]

# %%
coefficient_imp_2021 = filter_features_by_prefix(coefficient_df_2021)
coefficient_imp_2021
# Out:
#                                                Feature   Coefficient  \
# 21                derived_ethnicity_Hispanic or Latino -1.797556e-01
# 108          co-applicant_race_observed_Not applicable -1.411532e-01
# 22                             derived_ethnicity_Joint  1.391889e-01
# 109  co-applicant_race_observed_Not collected on th...  1.134165e-01
# 100        applicant_ethnicity_observed_Not applicable -1.131501e-01
# 105             applicant_race_observed_Not applicable -1.125002e-01
# 20           derived_ethnicity_Ethnicity Not Available -1.037648e-01
# 26              derived_race_Black or African American  9.521329e-02
# 25                                  derived_race_Asian  9.458476e-02
# 29                     derived_race_Race Not Available -8.256779e-02
# 23               derived_race_2 or more minority races  7.461746e-02
# 27                                  derived_race_Joint -6.566673e-02
# 24       derived_race_American Indian or Alaska Native  4.360461e-02
# 106  applicant_race_observed_Not collected on the b... -2.219479e-02
# 101  applicant_ethnicity_observed_Not collected on ... -1.725606e-02
# 104  co-applicant_ethnicity_observed_Not collected ...  1.370193e-02
# 107         co-applicant_race_observed_No co-applicant -1.288813e-02
# 102    co-applicant_ethnicity_observed_No co-applicant -1.275691e-02
# 28   derived_race_Native Hawaiian or Other Pacific ... -1.022215e-02
# 103     co-applicant_ethnicity_observed_Not applicable  1.399248e-09
#
#      abs_coefficient  odds_ratio
# 21      1.797556e-01    0.835474
# 108     1.411532e-01    0.868356
# 22      1.391889e-01    1.149341
# 109     1.134165e-01    1.120098
# 100     1.131501e-01    0.893017
# 105     1.125002e-01    0.893597
# 20      1.037648e-01    0.901437
# 26      9.521329e-02    1.099893
# 25      9.458476e-02    1.099202
# 29      8.256779e-02    0.920749
# 23      7.461746e-02    1.077472
# 27      6.566673e-02    0.936443
# 24      4.360461e-02    1.044569
# 106     2.219479e-02    0.978050
# 101     1.725606e-02    0.982892
# 104     1.370193e-02    1.013796
# 107     1.288813e-02    0.987195
# 102     1.275691e-02    0.987324
# 28      1.022215e-02    0.989830
# 103     1.399248e-09    1.000000

# %% [markdown]
# ## 2022

# %%
coefficient_sorted_2022 = deletezero_sort(coefficient_df_2022)
coefficient_sorted_2022
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91560/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.255622
# 50                         hoepa_status_Not applicable    -1.817515
# 49               hoepa_status_Not a high-cost mortgage     1.554290
# 39                       purchaser_type_Not applicable    -1.471624
# 33   purchaser_type_Commercial bank, savings bank, ...     0.829101
# ..                                                 ...          ...
# 60                                       total_units_3    -0.002690
# 72                             debt_to_income_ratio_45     0.000853
# 124                                applicant_age_35-44    -0.000842
# 137                               co-applicant_age_>74     0.000353
# 31                                   derived_sex_Joint     0.000165
#
#      abs_coefficient  odds_ratio
# 0           4.255622   70.500680
# 50          1.817515    0.162429
# 49          1.554290    4.731727
# 39          1.471624    0.229552
# 33          0.829101    2.291259
# ..               ...         ...
# 60          0.002690    0.997314
# 72          0.000853    1.000853
# 124         0.000842    0.999159
# 137         0.000353    1.000353
# 31          0.000165    1.000165
#
# [101 rows x 4 columns]

# %%
coefficient_imp_2022 = filter_features_by_prefix(coefficient_df_2022)
coefficient_imp_2022
# Out:
#                                                Feature  Coefficient  \
# 25                                  derived_race_Asian     0.256098
# 21                derived_ethnicity_Hispanic or Latino    -0.253583
# 20           derived_ethnicity_Ethnicity Not Available    -0.110892
# 100        applicant_ethnicity_observed_Not applicable    -0.081559
# 105             applicant_race_observed_Not applicable    -0.076629
# 29                     derived_race_Race Not Available    -0.070924
# 27                                  derived_race_Joint    -0.066976
# 26              derived_race_Black or African American    -0.065027
# 22                             derived_ethnicity_Joint    -0.052886
# 23               derived_race_2 or more minority races    -0.022515
# 103     co-applicant_ethnicity_observed_Not applicable    -0.019926
# 28   derived_race_Native Hawaiian or Other Pacific ...    -0.018910
# 24       derived_race_American Indian or Alaska Native    -0.012375
# 108          co-applicant_race_observed_Not applicable    -0.007173
# 106  applicant_race_observed_Not collected on the b...     0.002720
# 101  applicant_ethnicity_observed_Not collected on ...     0.000000
# 102    co-applicant_ethnicity_observed_No co-applicant     0.000000
# 104  co-applicant_ethnicity_observed_Not collected ...     0.000000
# 107         co-applicant_race_observed_No co-applicant     0.000000
# 109  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  odds_ratio
# 25          0.256098    1.291879
# 21          0.253583    0.776016
# 20          0.110892    0.895035
# 100         0.081559    0.921678
# 105         0.076629    0.926233
# 29          0.070924    0.931532
# 27          0.066976    0.935217
# 26          0.065027    0.937042
# 22          0.052886    0.948488
# 23          0.022515    0.977736
# 103         0.019926    0.980271
# 28          0.018910    0.981268
# 24          0.012375    0.987701
# 108         0.007173    0.992852
# 106         0.002720    1.002723
# 101         0.000000    1.000000
# 102         0.000000    1.000000
# 104         0.000000    1.000000
# 107         0.000000    1.000000
# 109         0.000000    1.000000
