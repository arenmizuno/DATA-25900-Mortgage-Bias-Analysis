# %%
#imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV, LogisticRegression, Lasso
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, r2_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_curve, roc_auc_score
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#split training and testing
def split_test_training(df):
    X_train, X_test, y_train, y_test = train_test_split(df.drop('rate_spread', axis=1), df['rate_spread'], test_size=0.2, random_state=42)
    
    # Fit the scaler on the training data and transform both the training and test data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Add a constant term for the intercept after scaling
    X_train_scaled = sm.add_constant(X_train_scaled, has_constant='add')
    X_test_scaled = sm.add_constant(X_test_scaled, has_constant='add')
    
    feature_names = df.drop('rate_spread', axis=1).columns.tolist()
    feature_names = ['const'] + feature_names
    X_train_scaled = pd.DataFrame(data=X_train_scaled, columns=feature_names)
    X_test_scaled = pd.DataFrame(data=X_test_scaled, columns=feature_names)

    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
def split_test_training(df):
    X_train, X_test, y_train, y_test = train_test_split(df.drop('rate_spread', axis=1), df['rate_spread'], test_size=0.2, random_state=42)
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
def ols_regression(X_train, X_test, y_train, y_test):
    ols_model = sm.OLS(y_train, X_train).fit()
    y_pred = ols_model.predict(X_test_sm)
    
    # Calculate the mean squared error on the test set
    mae = mean_absolute_error(y_test, y_pred)
    test_mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f'Test Mean Absolute Error (MAE): {mae}')
    print(f'Test MSE: {test_mse}')
    print(f'Test R-squared (R²) Score: {r2}')
    return ols_model

# %%
#print
def print_summary(ols_model, year):
    summary = ols_model.summary().as_text()
    lines = summary.split('\n')
    fig, ax = plt.subplots(figsize=(12, len(lines) * 0.3))
    ax.axis('off')
    for i, line in enumerate(lines):
        ax.text(0, len(lines) - i - 1, line, fontsize=10, fontfamily='monospace')
    plt.savefig(f'summary_{year}', bbox_inches='tight')
    plt.close()

# %%
#2018
dummy_2018 = pd.read_csv('dummy_2018_rs.csv')
X_train_2018, X_test_2018, y_train_2018, y_test_2018 = split_test_training(dummy_2018)
model_2018 = lasso_regression(X_train_2018, X_test_2018, y_train_2018, y_test_2018)
print_summary(model_2018 '2018')
# Out:
#        const  action_taken  loan_amount  loan_to_value_ratio  interest_rate  \
# 0        1.0           0.0     0.869190            -1.127267       2.512302
# 1        1.0           0.0    -0.616675             0.710308      -0.639841
# 2        1.0           0.0     0.069109             1.047110      -1.900698
# 3        1.0           0.0    -1.302459            -1.620449      -0.009412
# 4        1.0           0.0     0.983487            -1.076584       1.881874
# ...      ...           ...          ...                  ...            ...
# 11308    1.0           0.0     1.326379             0.764456      -0.324627
# 11309    1.0           0.0     0.754893            -2.159549      -0.955055
# 11310    1.0           0.0     1.212082             0.547863      -0.639841
# 11311    1.0           0.0    -0.273783            -1.076584       1.881874
# 11312    1.0           0.0     0.412001             0.710308      -0.009412
#
# ...

# %%
#2019
dummy_2019 = pd.read_csv('dummy_2019_rs.csv')
X_train_2019, X_test_2019, y_train_2019, y_test_2019 = split_test_training(dummy_2019)
model_2019 = lasso_regression(X_train_2019, X_test_2019, y_train_2019, y_test_2019)
print_summary(model_2019, '2019')

# %%
#2020
dummy_2020 = pd.read_csv('dummy_2020_rs.csv')
X_train_2020, X_test_2020, y_train_2020, y_test_2020 = split_test_training(dummy_2020)
model_2020 = lasso_regression(X_train_2020, X_test_2020, y_train_2020, y_test_2020)
print_summary(model_2020, '2020')

# %%
#2021
dummy_2021 = pd.read_csv('dummy_2021_rs.csv')
X_train_2021, X_test_2021, y_train_2021, y_test_2021 = split_test_training(dummy_2021)
model_2021 = lasso_regression(X_train_2021, X_test_2021, y_train_2021, y_test_2021)
print_summary(model_2021, '2021')

# %%
#2022
dummy_2022 = pd.read_csv('dummy_2022_rs.csv')
X_train_2022, X_test_2022, y_train_2022, y_test_2022 = split_test_training(dummy_2022)
model_2022 = lasso_regression(X_train_2022, X_test_2022, y_train_2022, y_test_2022)
print_summary(model_2022, '2022')
