# %%
# imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from functools import reduce
from sklearn.linear_model import Lasso, LogisticRegression, LassoCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, 
    mean_squared_error, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report, 
    roc_curve, 
    roc_auc_score
)
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# load all coefficient dfs
coefficient_df_2018 = pd.read_csv('coefficient_df_2018_noderived.csv')
coefficient_df_2019 = pd.read_csv('coefficient_df_2019_noderived.csv')
coefficient_df_2020 = pd.read_csv('coefficient_df_2020_noderived.csv')
coefficient_df_2021 = pd.read_csv('coefficient_df_2021_noderived.csv')
coefficient_df_2022 = pd.read_csv('coefficient_df_2022_noderived.csv')

# %%
# function that deletes all of the zero coefficients and sorts it
def deletezero_sort(df):
    df = df[df['Coefficient'] != 0]
    df['abs_coefficient'] = df['Coefficient'].abs()
    df['odds_ratio'] = np.exp(df['Coefficient'])
    df = df.sort_values(by='abs_coefficient', ascending=False)
    return df

# %%
# function that only keeps race, sex, and ethnicity features and sorts it
def filter_features_by_prefix(df):
    prefixes = ['derived_ethnicity', 'derived_race', 'applicant_ethnicity', 'co-applicant_ethnicity', 'applicant_race', 'co-applicant_race']
    filtered_coefficients = pd.DataFrame()
    for prefix in prefixes:
        filtered_coefficients = pd.concat([filtered_coefficients, df[df['Feature'].str.startswith(prefix)]])
    filtered_coefficients['abs_coefficient'] = filtered_coefficients['Coefficient'].abs()
    filtered_coefficients['odds_ratio'] = np.exp(filtered_coefficients['Coefficient'])
    filtered_coefficients = filtered_coefficients.sort_values(by='abs_coefficient', ascending=False)
    return filtered_coefficients

# %% [markdown]
# ## 2018

# %%
coefficient_sorted_2018 = deletezero_sort(coefficient_df_2018)
coefficient_sorted_2018
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.326909
# 27                       purchaser_type_Not applicable    -2.095382
# 38                         hoepa_status_Not applicable    -1.494023
# 37               hoepa_status_Not a high-cost mortgage     1.417875
# 149    initially_payable_to_institution_Not applicable    -0.772065
# ..                                                 ...          ...
# 85     co-applicant_credit_score_type_VantageScore 2.0     0.002783
# 59                             debt_to_income_ratio_42     0.002154
# 103  applicant_race-1_Native Hawaiian or Other Paci...    -0.002102
# 123  co-applicant_sex_Information not provided by a...    -0.001637
# 42   other_nonamortizing_features_Other non-fully a...    -0.001045
#
#      abs_coefficient  odds_ratio
# 0           4.326909   75.709869
# 27          2.095382    0.123023
# 38          1.494023    0.224468
# 37          1.417875    4.128339
# 149         0.772065    0.462058
# ..               ...         ...
# 85          0.002783    1.002787
# 59          0.002154    1.002156
# 103         0.002102    0.997900
# 123         0.001637    0.998365
# 42          0.001045    0.998956
#
# [76 rows x 4 columns]

# %%
coefficient_imp_2018 = filter_features_by_prefix(coefficient_df_2018)
coefficient_imp_2018
# Out:
#                                                Feature  Coefficient  \
# 87            applicant_ethnicity-1_Hispanic or Latino     0.298385
# 94         applicant_ethnicity_observed_Not applicable    -0.173462
# 112             applicant_race_observed_Not applicable    -0.150365
# 102  applicant_race-1_Information not provided by a...    -0.103439
# 90         co-applicant_ethnicity-1_Hispanic or Latino     0.091115
# 100                             applicant_race-1_Asian    -0.053660
# 99   applicant_race-1_American Indian or Alaska Native    -0.039051
# 105  co-applicant_race-1_American Indian or Alaska ...    -0.027088
# 95   applicant_ethnicity_observed_Not collected on ...    -0.012018
# 101         applicant_race-1_Black or African American    -0.009538
# 103  applicant_race-1_Native Hawaiian or Other Paci...    -0.002102
# 115          co-applicant_race_observed_Not applicable     0.000000
# 114         co-applicant_race_observed_No co-applicant     0.000000
# 111                 co-applicant_race-1_Not applicable     0.000000
# 110                co-applicant_race-1_No co-applicant     0.000000
# 109  co-applicant_race-1_Native Hawaiian or Other P...     0.000000
# 108  co-applicant_race-1_Information not provided b...     0.000000
# 107      co-applicant_race-1_Black or African American     0.000000
# 106                          co-applicant_race-1_Asian     0.000000
# 104                    applicant_race-1_Not applicable     0.000000
# 113  applicant_race_observed_Not collected on the b...     0.000000
# 89                applicant_ethnicity-1_Not applicable     0.000000
# 88   applicant_ethnicity-1_Information not provided...     0.000000
# 98   co-applicant_ethnicity_observed_Not collected ...     0.000000
# 97      co-applicant_ethnicity_observed_Not applicable     0.000000
# 96     co-applicant_ethnicity_observed_No co-applicant     0.000000
# 93             co-applicant_ethnicity-1_Not applicable     0.000000
# 92            co-applicant_ethnicity-1_No co-applicant     0.000000
# 91   co-applicant_ethnicity-1_Information not provi...     0.000000
# 116  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  odds_ratio
# 87          0.298385    1.347681
# 94          0.173462    0.840749
# 112         0.150365    0.860394
# 102         0.103439    0.901731
# 90          0.091115    1.095395
# 100         0.053660    0.947754
# 99          0.039051    0.961702
# 105         0.027088    0.973276
# 95          0.012018    0.988054
# 101         0.009538    0.990507
# 103         0.002102    0.997900
# 115         0.000000    1.000000
# 114         0.000000    1.000000
# 111         0.000000    1.000000
# 110         0.000000    1.000000
# 109         0.000000    1.000000
# 108         0.000000    1.000000
# 107         0.000000    1.000000
# 106         0.000000    1.000000
# 104         0.000000    1.000000
# 113         0.000000    1.000000
# 89          0.000000    1.000000
# 88          0.000000    1.000000
# 98          0.000000    1.000000
# 97          0.000000    1.000000
# 96          0.000000    1.000000
# 93          0.000000    1.000000
# 92          0.000000    1.000000
# 91          0.000000    1.000000
# 116         0.000000    1.000000

# %% [markdown]
# ## 2019

# %%
coefficient_sorted_2019 = deletezero_sort(coefficient_df_2019)
coefficient_sorted_2019
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.822151
# 26                       purchaser_type_Not applicable    -2.199681
# 38                         hoepa_status_Not applicable    -1.483152
# 37               hoepa_status_Not a high-cost mortgage     1.435640
# 145    initially_payable_to_institution_Not applicable    -0.830096
# ..                                                 ...          ...
# 81   co-applicant_credit_score_type_More than one c...    -0.002733
# 122  co-applicant_sex_Information not provided by a...     0.001809
# 136                             co-applicant_age_45-54    -0.001362
# 103                    applicant_race-1_Not applicable    -0.001344
# 89         co-applicant_ethnicity-1_Hispanic or Latino    -0.000146
#
#      abs_coefficient  odds_ratio
# 0           4.822151  124.232054
# 26          2.199681    0.110838
# 38          1.483152    0.226921
# 37          1.435640    4.202333
# 145         0.830096    0.436008
# ..               ...         ...
# 81          0.002733    0.997271
# 122         0.001809    1.001811
# 136         0.001362    0.998639
# 103         0.001344    0.998657
# 89          0.000146    0.999854
#
# [120 rows x 4 columns]

# %%
coefficient_imp_2019 = filter_features_by_prefix(coefficient_df_2019)
coefficient_imp_2019
# Out:
#                                                Feature  Coefficient  \
# 86            applicant_ethnicity-1_Hispanic or Latino     0.348047
# 111             applicant_race_observed_Not applicable    -0.173167
# 105                          co-applicant_race-1_Asian     0.158621
# 93         applicant_ethnicity_observed_Not applicable    -0.150301
# 99                              applicant_race-1_Asian    -0.106373
# 107  co-applicant_race-1_Information not provided b...    -0.095140
# 98   applicant_race-1_American Indian or Alaska Native    -0.093318
# 104  co-applicant_race-1_American Indian or Alaska ...    -0.058248
# 100         applicant_race-1_Black or African American    -0.049761
# 113         co-applicant_race_observed_No co-applicant    -0.047002
# 109                co-applicant_race-1_No co-applicant    -0.047002
# 110                 co-applicant_race-1_Not applicable     0.044313
# 102  applicant_race-1_Native Hawaiian or Other Paci...    -0.038788
# 87   applicant_ethnicity-1_Information not provided...     0.034855
# 115  co-applicant_race_observed_Not collected on th...     0.033044
# 112  applicant_race_observed_Not collected on the b...     0.029776
# 101  applicant_race-1_Information not provided by a...    -0.027363
# 106      co-applicant_race-1_Black or African American    -0.020986
# 95     co-applicant_ethnicity_observed_No co-applicant    -0.009863
# 91            co-applicant_ethnicity-1_No co-applicant    -0.009863
# 90   co-applicant_ethnicity-1_Information not provi...     0.008809
# 103                    applicant_race-1_Not applicable    -0.001344
# 89         co-applicant_ethnicity-1_Hispanic or Latino    -0.000146
# 97   co-applicant_ethnicity_observed_Not collected ...     0.000000
# 96      co-applicant_ethnicity_observed_Not applicable     0.000000
# 92             co-applicant_ethnicity-1_Not applicable     0.000000
# 108  co-applicant_race-1_Native Hawaiian or Other P...     0.000000
# 94   applicant_ethnicity_observed_Not collected on ...     0.000000
# 88                applicant_ethnicity-1_Not applicable     0.000000
# 114          co-applicant_race_observed_Not applicable     0.000000
#
#      abs_coefficient  odds_ratio
# 86          0.348047    1.416298
# 111         0.173167    0.840997
# 105         0.158621    1.171894
# 93          0.150301    0.860449
# 99          0.106373    0.899089
# 107         0.095140    0.909245
# 98          0.093318    0.910904
# 104         0.058248    0.943416
# 100         0.049761    0.951456
# 113         0.047002    0.954086
# 109         0.047002    0.954086
# 110         0.044313    1.045310
# 102         0.038788    0.961955
# 87          0.034855    1.035469
# 115         0.033044    1.033596
# 112         0.029776    1.030224
# 101         0.027363    0.973008
# 106         0.020986    0.979233
# 95          0.009863    0.990186
# 91          0.009863    0.990186
# 90          0.008809    1.008848
# 103         0.001344    0.998657
# 89          0.000146    0.999854
# 97          0.000000    1.000000
# 96          0.000000    1.000000
# 92          0.000000    1.000000
# 108         0.000000    1.000000
# 94          0.000000    1.000000
# 88          0.000000    1.000000
# 114         0.000000    1.000000

# %% [markdown]
# ## 2020

# %%
coefficient_sorted_2020 = deletezero_sort(coefficient_df_2020)
coefficient_sorted_2020
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature   Coefficient  \
# 0                                                const  4.911357e+00
# 27                       purchaser_type_Not applicable -1.964132e+00
# 39                         hoepa_status_Not applicable -1.618064e+00
# 38               hoepa_status_Not a high-cost mortgage  1.458156e+00
# 145    initially_payable_to_institution_Not applicable -6.795856e-01
# ..                                                 ...           ...
# 93             co-applicant_ethnicity-1_Not applicable  2.744489e-03
# 103  applicant_race-1_Native Hawaiian or Other Paci...  2.390725e-03
# 40      negative_amortization_No negative amortization  2.126576e-03
# 57                             debt_to_income_ratio_41 -1.334168e-03
# 48                                       total_units_2  3.309054e-10
#
#      abs_coefficient  odds_ratio
# 0       4.911357e+00  135.823624
# 27      1.964132e+00    0.140278
# 39      1.618064e+00    0.198282
# 38      1.458156e+00    4.298026
# 145     6.795856e-01    0.506827
# ..               ...         ...
# 93      2.744489e-03    1.002748
# 103     2.390725e-03    1.002394
# 40      2.126576e-03    1.002129
# 57      1.334168e-03    0.998667
# 48      3.309054e-10    1.000000
#
# [110 rows x 4 columns]

# %%
coefficient_imp_2020 = filter_features_by_prefix(coefficient_df_2020)
coefficient_imp_2020
# Out:
#                                                Feature  Coefficient  \
# 111             applicant_race_observed_Not applicable    -0.388555
# 102  applicant_race-1_Information not provided by a...    -0.380508
# 87            applicant_ethnicity-1_Hispanic or Latino     0.314771
# 94         applicant_ethnicity_observed_Not applicable    -0.181776
# 88   applicant_ethnicity-1_Information not provided...     0.155768
# 90         co-applicant_ethnicity-1_Hispanic or Latino     0.130827
# 95   applicant_ethnicity_observed_Not collected on ...    -0.124274
# 98   co-applicant_ethnicity_observed_Not collected ...     0.075533
# 106                          co-applicant_race-1_Asian    -0.065865
# 101         applicant_race-1_Black or African American    -0.048231
# 108  co-applicant_race-1_Information not provided b...    -0.028745
# 105  co-applicant_race-1_American Indian or Alaska ...    -0.018816
# 97      co-applicant_ethnicity_observed_Not applicable     0.014345
# 91   co-applicant_ethnicity-1_Information not provi...    -0.007345
# 114          co-applicant_race_observed_Not applicable     0.003050
# 93             co-applicant_ethnicity-1_Not applicable     0.002744
# 103  applicant_race-1_Native Hawaiian or Other Paci...     0.002391
# 107      co-applicant_race-1_Black or African American     0.000000
# 113         co-applicant_race_observed_No co-applicant     0.000000
# 110                co-applicant_race-1_No co-applicant     0.000000
# 109  co-applicant_race-1_Native Hawaiian or Other P...     0.000000
# 112  applicant_race_observed_Not collected on the b...     0.000000
# 89                applicant_ethnicity-1_Not applicable     0.000000
# 96     co-applicant_ethnicity_observed_No co-applicant     0.000000
# 104                    applicant_race-1_Not applicable     0.000000
# 92            co-applicant_ethnicity-1_No co-applicant     0.000000
# 100                             applicant_race-1_Asian     0.000000
# 99   applicant_race-1_American Indian or Alaska Native     0.000000
# 115  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  odds_ratio
# 111         0.388555    0.678036
# 102         0.380508    0.683514
# 87          0.314771    1.369945
# 94          0.181776    0.833788
# 88          0.155768    1.168555
# 90          0.130827    1.139770
# 95          0.124274    0.883138
# 98          0.075533    1.078458
# 106         0.065865    0.936258
# 101         0.048231    0.952914
# 108         0.028745    0.971665
# 105         0.018816    0.981360
# 97          0.014345    1.014449
# 91          0.007345    0.992681
# 114         0.003050    1.003054
# 93          0.002744    1.002748
# 103         0.002391    1.002394
# 107         0.000000    1.000000
# 113         0.000000    1.000000
# 110         0.000000    1.000000
# 109         0.000000    1.000000
# 112         0.000000    1.000000
# 89          0.000000    1.000000
# 96          0.000000    1.000000
# 104         0.000000    1.000000
# 92          0.000000    1.000000
# 100         0.000000    1.000000
# 99          0.000000    1.000000
# 115         0.000000    1.000000

# %% [markdown]
# ## 2021

# %%
coefficient_sorted_2021 = deletezero_sort(coefficient_df_2021)
coefficient_sorted_2021
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.066923
# 37                         hoepa_status_Not applicable    -1.465929
# 26                       purchaser_type_Not applicable    -1.429358
# 36               hoepa_status_Not a high-cost mortgage     1.333507
# 24                           purchaser_type_Ginnie Mae     0.676731
# ..                                                 ...          ...
# 119  co-applicant_sex_Co-applicant selected both ma...    -0.000751
# 94   applicant_ethnicity_observed_Not collected on ...    -0.000694
# 5                                               income     0.000605
# 121  co-applicant_sex_Information not provided by a...     0.000545
# 6                                     tract_population    -0.000026
#
#      abs_coefficient  odds_ratio
# 0           4.066923   58.377081
# 37          1.465929    0.230863
# 26          1.429358    0.239463
# 36          1.333507    3.794326
# 24          0.676731    1.967436
# ..               ...         ...
# 119         0.000751    0.999249
# 94          0.000694    0.999306
# 5           0.000605    1.000605
# 121         0.000545    1.000545
# 6           0.000026    0.999974
#
# [121 rows x 4 columns]

# %%
coefficient_imp_2021 = filter_features_by_prefix(coefficient_df_2021)
coefficient_imp_2021
# Out:
#                                                Feature  Coefficient  \
# 87            applicant_ethnicity-1_Hispanic or Latino    -0.159542
# 114  co-applicant_race_observed_Not collected on th...     0.108592
# 99                              applicant_race-1_Asian     0.101507
# 113          co-applicant_race_observed_Not applicable    -0.099398
# 88   applicant_ethnicity-1_Information not provided...    -0.091964
# 93         applicant_ethnicity_observed_Not applicable    -0.089497
# 110             applicant_race_observed_Not applicable    -0.088346
# 105                          co-applicant_race-1_Asian    -0.087765
# 100         applicant_race-1_Black or African American     0.083509
# 101  applicant_race-1_Information not provided by a...    -0.080042
# 91   co-applicant_ethnicity-1_Information not provi...    -0.021474
# 90         co-applicant_ethnicity-1_Hispanic or Latino    -0.014843
# 98   applicant_race-1_American Indian or Alaska Native     0.013507
# 97   co-applicant_ethnicity_observed_Not collected ...     0.009892
# 112         co-applicant_race_observed_No co-applicant    -0.009605
# 109                co-applicant_race-1_No co-applicant    -0.009605
# 95     co-applicant_ethnicity_observed_No co-applicant    -0.009491
# 92            co-applicant_ethnicity-1_No co-applicant    -0.009491
# 111  applicant_race_observed_Not collected on the b...    -0.002563
# 107  co-applicant_race-1_Information not provided b...     0.001311
# 106      co-applicant_race-1_Black or African American    -0.000868
# 94   applicant_ethnicity_observed_Not collected on ...    -0.000694
# 108  co-applicant_race-1_Native Hawaiian or Other P...     0.000000
# 89                applicant_ethnicity-1_Not applicable     0.000000
# 104  co-applicant_race-1_American Indian or Alaska ...     0.000000
# 103                    applicant_race-1_Not applicable     0.000000
# 96      co-applicant_ethnicity_observed_Not applicable     0.000000
# 102  applicant_race-1_Native Hawaiian or Other Paci...     0.000000
#
#      abs_coefficient  odds_ratio
# 87          0.159542    0.852534
# 114         0.108592    1.114707
# 99          0.101507    1.106838
# 113         0.099398    0.905382
# 88          0.091964    0.912138
# 93          0.089497    0.914391
# 110         0.088346    0.915444
# 105         0.087765    0.915976
# 100         0.083509    1.087096
# 101         0.080042    0.923078
# 91          0.021474    0.978755
# 90          0.014843    0.985266
# 98          0.013507    1.013599
# 97          0.009892    1.009941
# 112         0.009605    0.990441
# 109         0.009605    0.990441
# 95          0.009491    0.990554
# 92          0.009491    0.990554
# 111         0.002563    0.997441
# 107         0.001311    1.001312
# 106         0.000868    0.999132
# 94          0.000694    0.999306
# 108         0.000000    1.000000
# 89          0.000000    1.000000
# 104         0.000000    1.000000
# 103         0.000000    1.000000
# 96          0.000000    1.000000
# 102         0.000000    1.000000

# %% [markdown]
# ## 2022

# %%
coefficient_sorted_2022 = deletezero_sort(coefficient_df_2022)
coefficient_sorted_2022
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91547/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.419772
# 37                         hoepa_status_Not applicable    -1.874671
# 36               hoepa_status_Not a high-cost mortgage     1.610882
# 26                       purchaser_type_Not applicable    -1.508061
# 20   purchaser_type_Commercial bank, savings bank, ...     0.892117
# ..                                                 ...          ...
# 78   co-applicant_credit_score_type_Experian Fair I...     0.001712
# 80   co-applicant_credit_score_type_FICO Risk Score...    -0.001287
# 91   co-applicant_ethnicity-1_Information not provi...     0.001106
# 111                 co-applicant_race-1_Not applicable    -0.000774
# 109  co-applicant_race-1_Native Hawaiian or Other P...    -0.000274
#
#      abs_coefficient  odds_ratio
# 0           4.419772   83.077330
# 37          1.874671    0.153405
# 36          1.610882    5.007223
# 26          1.508061    0.221339
# 20          0.892117    2.440290
# ..               ...         ...
# 78          0.001712    1.001714
# 80          0.001287    0.998714
# 91          0.001106    1.001107
# 111         0.000774    0.999226
# 109         0.000274    0.999726
#
# [149 rows x 4 columns]

# %%
coefficient_imp_2022 = filter_features_by_prefix(coefficient_df_2022)
coefficient_imp_2022
# Out:
#                                                Feature  Coefficient  \
# 87            applicant_ethnicity-1_Hispanic or Latino    -0.297845
# 100                             applicant_race-1_Asian     0.285568
# 88   applicant_ethnicity-1_Information not provided...    -0.134322
# 94         applicant_ethnicity_observed_Not applicable    -0.095333
# 112             applicant_race_observed_Not applicable    -0.092915
# 102  applicant_race-1_Information not provided by a...    -0.091829
# 101         applicant_race-1_Black or African American    -0.090880
# 108  co-applicant_race-1_Information not provided b...     0.052213
# 99   applicant_race-1_American Indian or Alaska Native    -0.052072
# 106                          co-applicant_race-1_Asian    -0.046303
# 103  applicant_race-1_Native Hawaiian or Other Paci...    -0.039191
# 90         co-applicant_ethnicity-1_Hispanic or Latino     0.036525
# 97      co-applicant_ethnicity_observed_Not applicable    -0.035744
# 107      co-applicant_race-1_Black or African American     0.035153
# 114         co-applicant_race_observed_No co-applicant     0.030628
# 96     co-applicant_ethnicity_observed_No co-applicant     0.030628
# 110                co-applicant_race-1_No co-applicant     0.030628
# 92            co-applicant_ethnicity-1_No co-applicant     0.030628
# 115          co-applicant_race_observed_Not applicable    -0.023621
# 113  applicant_race_observed_Not collected on the b...     0.013348
# 105  co-applicant_race-1_American Indian or Alaska ...    -0.012388
# 93             co-applicant_ethnicity-1_Not applicable    -0.010916
# 116  co-applicant_race_observed_Not collected on th...    -0.008000
# 95   applicant_ethnicity_observed_Not collected on ...     0.006617
# 98   co-applicant_ethnicity_observed_Not collected ...    -0.005063
# 91   co-applicant_ethnicity-1_Information not provi...     0.001106
# 111                 co-applicant_race-1_Not applicable    -0.000774
# 109  co-applicant_race-1_Native Hawaiian or Other P...    -0.000274
# 104                    applicant_race-1_Not applicable     0.000000
# 89                applicant_ethnicity-1_Not applicable     0.000000
#
#      abs_coefficient  odds_ratio
# 87          0.297845    0.742416
# 100         0.285568    1.330517
# 88          0.134322    0.874308
# 94          0.095333    0.909070
# 112         0.092915    0.911271
# 102         0.091829    0.912261
# 101         0.090880    0.913127
# 108         0.052213    1.053601
# 99          0.052072    0.949260
# 106         0.046303    0.954753
# 103         0.039191    0.961567
# 90          0.036525    1.037200
# 97          0.035744    0.964887
# 107         0.035153    1.035779
# 114         0.030628    1.031102
# 96          0.030628    1.031102
# 110         0.030628    1.031102
# 92          0.030628    1.031102
# 115         0.023621    0.976656
# 113         0.013348    1.013437
# 105         0.012388    0.987689
# 93          0.010916    0.989143
# 116         0.008000    0.992032
# 95          0.006617    1.006639
# 98          0.005063    0.994950
# 91          0.001106    1.001107
# 111         0.000774    0.999226
# 109         0.000274    0.999726
# 104         0.000000    1.000000
# 89          0.000000    1.000000
