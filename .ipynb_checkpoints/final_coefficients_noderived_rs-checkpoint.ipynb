# %%
# imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, LogisticRegression, LassoCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, 
    mean_squared_error, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report, 
    roc_curve, 
    roc_auc_score
)
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# load all coefficient dfs
coefficient_df_2018 = pd.read_csv('coefficient_df_2018_noderived_rs.csv')
coefficient_df_2019 = pd.read_csv('coefficient_df_2019_noderived_rs.csv')
coefficient_df_2020 = pd.read_csv('coefficient_df_2020_noderived_rs.csv')
coefficient_df_2021 = pd.read_csv('coefficient_df_2021_noderived_rs.csv')
coefficient_df_2022 = pd.read_csv('coefficient_df_2022_noderived_rs.csv')

# %%
# function that deletes all of the zero coefficients and sorts it
def deletezero_sort(df):
    df = df[df['Coefficient'] != 0]
    df['abs_coefficient'] = df['Coefficient'].abs()
    df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
    df = df.sort_values(by='abs_coefficient', ascending=False)
    return df

# %%
# function that only keeps race, sex, and ethnicity features and sorts it
def filter_features_by_prefix(df):
    prefixes = ['derived_ethnicity', 'derived_race', 'applicant_ethnicity', 'co-applicant_ethnicity', 'applicant_race', 'co-applicant_race']
    filtered_coefficients = pd.DataFrame()
    for prefix in prefixes:
        filtered_coefficients = pd.concat([filtered_coefficients, df[df['Feature'].str.startswith(prefix)]])
    filtered_coefficients['abs_coefficient'] = filtered_coefficients['Coefficient'].abs()
    filtered_coefficients['pct_increase/decrease'] = (np.exp(filtered_coefficients['Coefficient'])-1)*100
    filtered_coefficients = filtered_coefficients.sort_values(by='abs_coefficient', ascending=False)
    return filtered_coefficients

# %% [markdown]
# ## 2018

# %%
coefficient_sorted_2018 = deletezero_sort(coefficient_df_2018)
coefficient_sorted_2018
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                               Feature   Coefficient  \
# 3                                       interest_rate  2.742972e-01
# 18           derived_loan_product_type_FHA:First Lien  2.070781e-01
# 2                                 loan_to_value_ratio  1.693008e-01
# 1                                         loan_amount -1.120729e-01
# 20            derived_loan_product_type_VA:First Lien -8.349031e-02
# ..                                                ...           ...
# 45                     construction_method_Site-built -2.465696e-06
# 19       derived_loan_product_type_FSA/RHS:First Lien -9.274973e-07
# 36          lien_status_Secured by a subordinate lien  9.014665e-09
# 46  manufactured_home_secured_property_type_Not ap... -9.708134e-17
# 47  manufactured_home_land_property_interest_Not a... -2.002082e-18
#
#     abs_coefficient  pct_increase/decrease
# 3      2.742972e-01           3.156057e+01
# 18     2.070781e-01           2.300786e+01
# 2      1.693008e-01           1.844764e+01
# 1      1.120729e-01          -1.060209e+01
# 20     8.349031e-02          -8.010000e+00
# ..              ...                    ...
# 45     2.465696e-06          -2.465693e-04
# 19     9.274973e-07          -9.274969e-05
# 36     9.014665e-09           9.014665e-07
# 46     9.708134e-17          -1.110223e-14
# 47     2.002082e-18           0.000000e+00
#
# [131 rows x 4 columns]

# %%
coefficient_imp_2018 = filter_features_by_prefix(coefficient_df_2018)
coefficient_imp_2018
# Out:
#                                                Feature  Coefficient  \
# 94   applicant_ethnicity_observed_Not collected on ...     0.019749
# 111             applicant_race_observed_Not applicable     0.013124
# 100         applicant_race-1_Black or African American     0.012833
# 112  applicant_race_observed_Not collected on the b...     0.008763
# 86            applicant_ethnicity-1_Hispanic or Latino     0.007688
# 105                          co-applicant_race-1_Asian     0.004852
# 90   co-applicant_ethnicity-1_Information not provi...    -0.002926
# 106      co-applicant_race-1_Black or African American     0.002701
# 103                    applicant_race-1_Not applicable    -0.002564
# 101  applicant_race-1_Information not provided by a...    -0.002442
# 115  co-applicant_race_observed_Not collected on th...    -0.002187
# 89         co-applicant_ethnicity-1_Hispanic or Latino     0.001881
# 114          co-applicant_race_observed_Not applicable    -0.001697
# 92             co-applicant_ethnicity-1_Not applicable    -0.001251
# 108  co-applicant_race-1_Native Hawaiian or Other P...     0.001115
# 109                co-applicant_race-1_No co-applicant     0.001088
# 98   applicant_race-1_American Indian or Alaska Native     0.000800
# 110                 co-applicant_race-1_Not applicable     0.000651
# 99                              applicant_race-1_Asian     0.000447
# 102  applicant_race-1_Native Hawaiian or Other Paci...     0.000223
# 104  co-applicant_race-1_American Indian or Alaska ...     0.000103
# 113         co-applicant_race_observed_No co-applicant     0.000073
# 93         applicant_ethnicity_observed_Not applicable     0.000000
# 88                applicant_ethnicity-1_Not applicable    -0.000000
# 107  co-applicant_race-1_Information not provided b...     0.000000
# 97   co-applicant_ethnicity_observed_Not collected ...     0.000000
# 91            co-applicant_ethnicity-1_No co-applicant    -0.000000
# 87   applicant_ethnicity-1_Information not provided...    -0.000000
# 95     co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 96      co-applicant_ethnicity_observed_Not applicable    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 94          0.019749               1.994535
# 111         0.013124               1.321063
# 100         0.012833               1.291550
# 112         0.008763               0.880105
# 86          0.007688               0.771774
# 105         0.004852               0.486403
# 90          0.002926              -0.292188
# 106         0.002701               0.270454
# 103         0.002564              -0.256070
# 101         0.002442              -0.243903
# 115         0.002187              -0.218414
# 89          0.001881               0.188288
# 114         0.001697              -0.169546
# 92          0.001251              -0.124985
# 108         0.001115               0.111522
# 109         0.001088               0.108869
# 98          0.000800               0.080024
# 110         0.000651               0.065095
# 99          0.000447               0.044705
# 102         0.000223               0.022314
# 104         0.000103               0.010278
# 113         0.000073               0.007264
# 93          0.000000               0.000000
# 88          0.000000               0.000000
# 107         0.000000               0.000000
# 97          0.000000               0.000000
# 91          0.000000               0.000000
# 87          0.000000               0.000000
# 95          0.000000               0.000000
# 96          0.000000               0.000000

# %% [markdown]
# ## 2019

# %%
coefficient_sorted_2019 = deletezero_sort(coefficient_df_2019)
coefficient_sorted_2019
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature   Coefficient  \
# 3                                        interest_rate  2.890123e-01
# 18            derived_loan_product_type_FHA:First Lien  2.303368e-01
# 2                                  loan_to_value_ratio  1.471619e-01
# 1                                          loan_amount -1.018165e-01
# 20             derived_loan_product_type_VA:First Lien -7.042396e-02
# ..                                                 ...           ...
# 111         co-applicant_race_observed_No co-applicant  9.404624e-07
# 44                      construction_method_Site-built -5.938850e-07
# 35           lien_status_Secured by a subordinate lien -2.034577e-07
# 45   manufactured_home_secured_property_type_Not ap... -5.770974e-17
# 46   manufactured_home_land_property_interest_Not a... -6.354298e-20
#
#      abs_coefficient  pct_increase/decrease
# 3       2.890123e-01           3.351082e+01
# 18      2.303368e-01           2.590239e+01
# 2       1.471619e-01           1.585415e+01
# 1       1.018165e-01          -9.680471e+00
# 20      7.042396e-02          -6.800139e+00
# ..               ...                    ...
# 111     9.404624e-07           9.404628e-05
# 44      5.938850e-07          -5.938848e-05
# 35      2.034577e-07          -2.034577e-05
# 45      5.770974e-17          -1.110223e-14
# 46      6.354298e-20           0.000000e+00
#
# [134 rows x 4 columns]

# %%
coefficient_imp_2019 = filter_features_by_prefix(coefficient_df_2019)
coefficient_imp_2019
# Out:
#                                                Feature   Coefficient  \
# 108                co-applicant_race-1_No co-applicant  4.072841e-02
# 109             applicant_race_observed_Not applicable -3.885511e-02
# 112          co-applicant_race_observed_Not applicable  2.210627e-02
# 85            applicant_ethnicity-1_Hispanic or Latino  1.777215e-02
# 92         applicant_ethnicity_observed_Not applicable  1.744735e-02
# 99          applicant_race-1_Black or African American  1.683514e-02
# 89   co-applicant_ethnicity-1_Information not provi...  8.732870e-03
# 88         co-applicant_ethnicity-1_Hispanic or Latino  8.451483e-03
# 113  co-applicant_race_observed_Not collected on th... -8.418922e-03
# 86   applicant_ethnicity-1_Information not provided...  7.932666e-03
# 102                    applicant_race-1_Not applicable -5.547457e-03
# 110  applicant_race_observed_Not collected on the b...  5.059063e-03
# 104                          co-applicant_race-1_Asian  4.982371e-03
# 93   applicant_ethnicity_observed_Not collected on ...  4.864048e-03
# 106  co-applicant_race-1_Information not provided b... -3.378662e-03
# 105      co-applicant_race-1_Black or African American  2.625152e-03
# 95      co-applicant_ethnicity_observed_Not applicable  1.666799e-03
# 97   applicant_race-1_American Indian or Alaska Native -1.395246e-03
# 98                              applicant_race-1_Asian -1.317278e-03
# 100  applicant_race-1_Information not provided by a... -1.149910e-03
# 107  co-applicant_race-1_Native Hawaiian or Other P... -8.608212e-04
# 101  applicant_race-1_Native Hawaiian or Other Paci...  5.553960e-04
# 91             co-applicant_ethnicity-1_Not applicable  3.889022e-04
# 87                applicant_ethnicity-1_Not applicable  2.595768e-04
# 103  co-applicant_race-1_American Indian or Alaska ... -4.703345e-05
# 111         co-applicant_race_observed_No co-applicant  9.404624e-07
# 90            co-applicant_ethnicity-1_No co-applicant  0.000000e+00
# 96   co-applicant_ethnicity_observed_Not collected ... -0.000000e+00
# 94     co-applicant_ethnicity_observed_No co-applicant  0.000000e+00
#
#      abs_coefficient  pct_increase/decrease
# 108     4.072841e-02               4.156919
# 109     3.885511e-02              -3.810993
# 112     2.210627e-02               2.235243
# 85      1.777215e-02               1.793102
# 92      1.744735e-02               1.760045
# 99      1.683514e-02               1.697765
# 89      8.732870e-03               0.877111
# 88      8.451483e-03               0.848730
# 113     8.418922e-03              -0.838358
# 86      7.932666e-03               0.796421
# 102     5.547457e-03              -0.553210
# 110     5.059063e-03               0.507188
# 104     4.982371e-03               0.499480
# 93      4.864048e-03               0.487590
# 106     3.378662e-03              -0.337296
# 105     2.625152e-03               0.262860
# 95      1.666799e-03               0.166819
# 97      1.395246e-03              -0.139427
# 98      1.317278e-03              -0.131641
# 100     1.149910e-03              -0.114925
# 107     8.608212e-04              -0.086045
# 101     5.553960e-04               0.055555
# 91      3.889022e-04               0.038898
# 87      2.595768e-04               0.025961
# 103     4.703345e-05              -0.004703
# 111     9.404624e-07               0.000094
# 90      0.000000e+00               0.000000
# 96      0.000000e+00               0.000000
# 94      0.000000e+00               0.000000

# %% [markdown]
# ## 2020

# %%
coefficient_sorted_2020 = deletezero_sort(coefficient_df_2020)
coefficient_sorted_2020
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                               Feature   Coefficient  \
# 3                                       interest_rate  2.321139e-01
# 18           derived_loan_product_type_FHA:First Lien  2.166904e-01
# 2                                 loan_to_value_ratio  1.296059e-01
# 1                                         loan_amount -1.180787e-01
# 20            derived_loan_product_type_VA:First Lien -6.500531e-02
# ..                                                ...           ...
# 10                  tract_minority_population_percent -1.580299e-05
# 35          lien_status_Secured by a subordinate lien -1.491124e-06
# 44                     construction_method_Site-built -1.356132e-07
# 45  manufactured_home_secured_property_type_Not ap... -3.126323e-16
# 46  manufactured_home_land_property_interest_Not a... -4.335570e-17
#
#     abs_coefficient  pct_increase/decrease
# 3      2.321139e-01           2.612634e+01
# 18     2.166904e-01           2.419595e+01
# 2      1.296059e-01           1.383797e+01
# 1      1.180787e-01          -1.113739e+01
# 20     6.500531e-02          -6.293751e+00
# ..              ...                    ...
# 10     1.580299e-05          -1.580287e-03
# 35     1.491124e-06          -1.491123e-04
# 44     1.356132e-07          -1.356132e-05
# 45     3.126323e-16          -3.330669e-14
# 46     4.335570e-17           0.000000e+00
#
# [125 rows x 4 columns]

# %%
coefficient_imp_2020 = filter_features_by_prefix(coefficient_df_2020)
coefficient_imp_2020
# Out:
#                                                Feature  Coefficient  \
# 91         applicant_ethnicity_observed_Not applicable     0.018587
# 98          applicant_race-1_Black or African American     0.018342
# 85            applicant_ethnicity-1_Hispanic or Latino     0.016338
# 95   co-applicant_ethnicity_observed_Not collected ...     0.014273
# 87         co-applicant_ethnicity-1_Hispanic or Latino     0.007655
# 86   applicant_ethnicity-1_Information not provided...     0.005129
# 103                          co-applicant_race-1_Asian     0.004857
# 99   applicant_race-1_Information not provided by a...     0.004733
# 104      co-applicant_race-1_Black or African American     0.003967
# 88   co-applicant_ethnicity-1_Information not provi...    -0.003911
# 94      co-applicant_ethnicity_observed_Not applicable    -0.003460
# 90             co-applicant_ethnicity-1_Not applicable     0.002533
# 109  applicant_race_observed_Not collected on the b...     0.002293
# 105  co-applicant_race-1_Information not provided b...     0.002211
# 100  applicant_race-1_Native Hawaiian or Other Paci...     0.001138
# 102  co-applicant_race-1_American Indian or Alaska ...    -0.001002
# 96   applicant_race-1_American Indian or Alaska Native     0.000837
# 106  co-applicant_race-1_Native Hawaiian or Other P...    -0.000780
# 97                              applicant_race-1_Asian    -0.000435
# 92   applicant_ethnicity_observed_Not collected on ...     0.000411
# 111          co-applicant_race_observed_Not applicable     0.000000
# 110         co-applicant_race_observed_No co-applicant     0.000000
# 107                co-applicant_race-1_No co-applicant     0.000000
# 93     co-applicant_ethnicity_observed_No co-applicant     0.000000
# 108             applicant_race_observed_Not applicable     0.000000
# 101                    applicant_race-1_Not applicable    -0.000000
# 89            co-applicant_ethnicity-1_No co-applicant     0.000000
# 112  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  pct_increase/decrease
# 91          0.018587               1.876033
# 98          0.018342               1.851170
# 85          0.016338               1.647261
# 95          0.014273               1.437583
# 87          0.007655               0.768408
# 86          0.005129               0.514248
# 103         0.004857               0.486845
# 99          0.004733               0.474419
# 104         0.003967               0.397473
# 88          0.003911              -0.390373
# 94          0.003460              -0.345436
# 90          0.002533               0.253572
# 109         0.002293               0.229548
# 105         0.002211               0.221385
# 100         0.001138               0.113891
# 102         0.001002              -0.100144
# 96          0.000837               0.083762
# 106         0.000780              -0.077937
# 97          0.000435              -0.043519
# 92          0.000411               0.041133
# 111         0.000000               0.000000
# 110         0.000000               0.000000
# 107         0.000000               0.000000
# 93          0.000000               0.000000
# 108         0.000000               0.000000
# 101         0.000000               0.000000
# 89          0.000000               0.000000
# 112         0.000000               0.000000

# %% [markdown]
# ## 2021

# %%
coefficient_sorted_2021 = deletezero_sort(coefficient_df_2021)
coefficient_sorted_2021
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature   Coefficient  \
# 3                                        interest_rate  2.497130e-01
# 18            derived_loan_product_type_FHA:First Lien  2.315352e-01
# 1                                          loan_amount -1.415486e-01
# 2                                  loan_to_value_ratio  1.194405e-01
# 7                                       property_value  6.506674e-02
# ..                                                 ...           ...
# 44                      construction_method_Site-built -1.182795e-04
# 130                             co-applicant_age_35-44  1.042333e-04
# 33   loan_type_USDA Rural Housing Service or Farm S...  8.409101e-05
# 45   manufactured_home_secured_property_type_Not ap... -1.977021e-17
# 46   manufactured_home_land_property_interest_Not a... -1.931943e-19
#
#      abs_coefficient  pct_increase/decrease
# 3       2.497130e-01              28.365689
# 18      2.315352e-01              26.053372
# 1       1.415486e-01             -13.198700
# 2       1.194405e-01              12.686617
# 7       6.506674e-02               6.723025
# ..               ...                    ...
# 44      1.182795e-04              -0.011827
# 130     1.042333e-04               0.010424
# 33      8.409101e-05               0.008409
# 45      1.977021e-17               0.000000
# 46      1.931943e-19               0.000000
#
# [123 rows x 4 columns]

# %%
coefficient_imp_2021 = filter_features_by_prefix(coefficient_df_2021)
coefficient_imp_2021
# Out:
#                                                Feature  Coefficient  \
# 98          applicant_race-1_Black or African American     0.011287
# 85            applicant_ethnicity-1_Hispanic or Latino     0.005975
# 95   co-applicant_ethnicity_observed_Not collected ...     0.005532
# 86   applicant_ethnicity-1_Information not provided...     0.004343
# 111  co-applicant_race_observed_Not collected on th...     0.003100
# 103      co-applicant_race-1_Black or African American     0.002975
# 88         co-applicant_ethnicity-1_Hispanic or Latino     0.002707
# 92   applicant_ethnicity_observed_Not collected on ...    -0.002190
# 104  co-applicant_race-1_Information not provided b...     0.001880
# 97                              applicant_race-1_Asian    -0.001733
# 102                          co-applicant_race-1_Asian     0.001312
# 99   applicant_race-1_Information not provided by a...    -0.001218
# 100  applicant_race-1_Native Hawaiian or Other Paci...     0.000686
# 89   co-applicant_ethnicity-1_Information not provi...    -0.000613
# 96   applicant_race-1_American Indian or Alaska Native     0.000388
# 101  co-applicant_race-1_American Indian or Alaska ...    -0.000351
# 107             applicant_race_observed_Not applicable    -0.000322
# 105  co-applicant_race-1_Native Hawaiian or Other P...     0.000276
# 94      co-applicant_ethnicity_observed_Not applicable     0.000000
# 91         applicant_ethnicity_observed_Not applicable    -0.000000
# 108  applicant_race_observed_Not collected on the b...     0.000000
# 93     co-applicant_ethnicity_observed_No co-applicant     0.000000
# 90            co-applicant_ethnicity-1_No co-applicant     0.000000
# 106                co-applicant_race-1_No co-applicant    -0.000000
# 109         co-applicant_race_observed_No co-applicant    -0.000000
# 110          co-applicant_race_observed_Not applicable     0.000000
# 87                applicant_ethnicity-1_Not applicable    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 98          0.011287               1.135122
# 85          0.005975               0.599320
# 95          0.005532               0.554746
# 86          0.004343               0.435238
# 111         0.003100               0.310474
# 103         0.002975               0.297904
# 88          0.002707               0.271096
# 92          0.002190              -0.218753
# 104         0.001880               0.188158
# 97          0.001733              -0.173119
# 102         0.001312               0.131258
# 99          0.001218              -0.121689
# 100         0.000686               0.068626
# 89          0.000613              -0.061251
# 96          0.000388               0.038843
# 101         0.000351              -0.035068
# 107         0.000322              -0.032208
# 105         0.000276               0.027595
# 94          0.000000               0.000000
# 91          0.000000               0.000000
# 108         0.000000               0.000000
# 93          0.000000               0.000000
# 90          0.000000               0.000000
# 106         0.000000               0.000000
# 109         0.000000               0.000000
# 110         0.000000               0.000000
# 87          0.000000               0.000000

# %% [markdown]
# ## 2022

# %%
coefficient_sorted_2022 = deletezero_sort(coefficient_df_2022)
coefficient_sorted_2022
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92390/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature   Coefficient  \
# 18            derived_loan_product_type_FHA:First Lien  1.902618e-01
# 1                                          loan_amount -1.869736e-01
# 2                                  loan_to_value_ratio  1.510580e-01
# 21             derived_loan_product_type_VA:First Lien -1.113596e-01
# 3                                        interest_rate  9.738372e-02
# ..                                                 ...           ...
# 43                  balloon_payment_No balloon payment -1.149849e-04
# 106                          co-applicant_race-1_Asian  1.107011e-04
# 100  applicant_race-1_American Indian or Alaska Native  8.289940e-05
# 46   manufactured_home_secured_property_type_Not ap... -2.322531e-16
# 47   manufactured_home_land_property_interest_Not a... -2.341565e-17
#
#      abs_coefficient  pct_increase/decrease
# 18      1.902618e-01           2.095663e+01
# 1       1.869736e-01          -1.705344e+01
# 2       1.510580e-01           1.630641e+01
# 21      1.113596e-01          -1.053830e+01
# 3       9.738372e-02           1.022833e+01
# ..               ...                    ...
# 43      1.149849e-04          -1.149783e-02
# 106     1.107011e-04           1.107073e-02
# 100     8.289940e-05           8.290284e-03
# 46      2.322531e-16          -2.220446e-14
# 47      2.341565e-17           0.000000e+00
#
# [127 rows x 4 columns]

# %%
coefficient_imp_2022 = filter_features_by_prefix(coefficient_df_2022)
coefficient_imp_2022
# Out:
#                                                Feature  Coefficient  \
# 96   applicant_ethnicity_observed_Not collected on ...    -0.024871
# 113  applicant_race_observed_Not collected on the b...    -0.019379
# 101                             applicant_race-1_Asian    -0.016863
# 102         applicant_race-1_Black or African American     0.014264
# 91         co-applicant_ethnicity-1_Hispanic or Latino     0.011673
# 88            applicant_ethnicity-1_Hispanic or Latino    -0.004518
# 94             co-applicant_ethnicity-1_Not applicable     0.004445
# 89   applicant_ethnicity-1_Information not provided...     0.004335
# 107      co-applicant_race-1_Black or African American     0.003832
# 108  co-applicant_race-1_Information not provided b...    -0.003614
# 90                applicant_ethnicity-1_Not applicable    -0.002938
# 104  applicant_race-1_Native Hawaiian or Other Paci...    -0.002640
# 103  applicant_race-1_Information not provided by a...     0.002566
# 92   co-applicant_ethnicity-1_Information not provi...     0.002214
# 105  co-applicant_race-1_American Indian or Alaska ...     0.000747
# 111                 co-applicant_race-1_Not applicable     0.000341
# 106                          co-applicant_race-1_Asian     0.000111
# 100  applicant_race-1_American Indian or Alaska Native     0.000083
# 115          co-applicant_race_observed_Not applicable     0.000000
# 114         co-applicant_race_observed_No co-applicant    -0.000000
# 110                co-applicant_race-1_No co-applicant    -0.000000
# 109  co-applicant_race-1_Native Hawaiian or Other P...     0.000000
# 112             applicant_race_observed_Not applicable    -0.000000
# 93            co-applicant_ethnicity-1_No co-applicant    -0.000000
# 95         applicant_ethnicity_observed_Not applicable    -0.000000
# 99   co-applicant_ethnicity_observed_Not collected ...    -0.000000
# 98      co-applicant_ethnicity_observed_Not applicable    -0.000000
# 97     co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 116  co-applicant_race_observed_Not collected on th...    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 96          0.024871              -2.456387
# 113         0.019379              -1.919277
# 101         0.016863              -1.672139
# 102         0.014264               1.436664
# 91          0.011673               1.174136
# 88          0.004518              -0.450829
# 94          0.004445               0.445513
# 89          0.004335               0.434481
# 107         0.003832               0.383916
# 108         0.003614              -0.360795
# 90          0.002938              -0.293324
# 104         0.002640              -0.263696
# 103         0.002566               0.256912
# 92          0.002214               0.221617
# 105         0.000747               0.074763
# 111         0.000341               0.034112
# 106         0.000111               0.011071
# 100         0.000083               0.008290
# 115         0.000000               0.000000
# 114         0.000000               0.000000
# 110         0.000000               0.000000
# 109         0.000000               0.000000
# 112         0.000000               0.000000
# 93          0.000000               0.000000
# 95          0.000000               0.000000
# 99          0.000000               0.000000
# 98          0.000000               0.000000
# 97          0.000000               0.000000
# 116         0.000000               0.000000
