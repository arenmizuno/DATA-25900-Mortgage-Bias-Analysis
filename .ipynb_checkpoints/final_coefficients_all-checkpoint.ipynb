# %%
# imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from functools import reduce
from sklearn.linear_model import Lasso, LogisticRegression, LassoCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, 
    mean_squared_error, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report, 
    roc_curve, 
    roc_auc_score
)
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# load all coefficient dfs
coefficient_df_2018 = pd.read_csv('coefficient_df_2018_all.csv')
coefficient_df_2019 = pd.read_csv('coefficient_df_2019_all.csv')
coefficient_df_2020 = pd.read_csv('coefficient_df_2020_all.csv')
coefficient_df_2021 = pd.read_csv('coefficient_df_2021_all.csv')
coefficient_df_2022 = pd.read_csv('coefficient_df_2022_all.csv')

# %%
# function that deletes all of the zero coefficients and sorts it
def deletezero_sort(df):
    df = df[df['Coefficient'] != 0]
    df['abs_coefficient'] = df['Coefficient'].abs()
    df['odds_ratio'] = np.exp(df['Coefficient'])
    df = df.sort_values(by='abs_coefficient', ascending=False)
    return df

# %%
# function that only keeps race, sex, and ethnicity features and sorts it
def filter_features_by_prefix(df):
    prefixes = ['derived_ethnicity', 'derived_race', 'applicant_ethnicity', 'co-applicant_ethnicity', 'applicant_race', 'co-applicant_race']
    filtered_coefficients = pd.DataFrame()
    for prefix in prefixes:
        filtered_coefficients = pd.concat([filtered_coefficients, df[df['Feature'].str.startswith(prefix)]])
    filtered_coefficients['abs_coefficient'] = filtered_coefficients['Coefficient'].abs()
    filtered_coefficients['odds_ratio'] = np.exp(filtered_coefficients['Coefficient'])
    filtered_coefficients = filtered_coefficients.sort_values(by='abs_coefficient', ascending=False)
    return filtered_coefficients

# %% [markdown]
# ## 2018

# %%
coefficient_sorted_2018 = deletezero_sort(coefficient_df_2018)
coefficient_sorted_2018
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.327318
# ...

# %%
coefficient_imp_2018 = filter_features_by_prefix(coefficient_df_2018)
coefficient_imp_2018
# Out:
#                                                Feature  Coefficient  \
# 21                derived_ethnicity_Hispanic or Latino     0.209138
# 107        applicant_ethnicity_observed_Not applicable    -0.171393
# 125             applicant_race_observed_Not applicable    -0.148836
# 100           applicant_ethnicity-1_Hispanic or Latino     0.114214
# 103        co-applicant_ethnicity-1_Hispanic or Latino     0.075874
# 22                             derived_ethnicity_Joint    -0.056099
# 29                     derived_race_Race Not Available    -0.050488
# 115  applicant_race-1_Information not provided by a...    -0.048077
# 112  applicant_race-1_American Indian or Alaska Native    -0.040649
# 25                                  derived_race_Asian    -0.039442
# 118  co-applicant_race-1_American Indian or Alaska ...    -0.025313
# 113                             applicant_race-1_Asian    -0.013559
# 108  applicant_ethnicity_observed_Not collected on ...    -0.012093
# ...

# %% [markdown]
# ## 2019

# %%
coefficient_sorted_2019 = deletezero_sort(coefficient_df_2019)
coefficient_sorted_2019
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.823885
# ...

# %%
coefficient_imp_2019 = filter_features_by_prefix(coefficient_df_2019)
coefficient_imp_2019
# Out:
#                                                Feature  Coefficient  \
# 21                derived_ethnicity_Hispanic or Latino     0.209165
# 124             applicant_race_observed_Not applicable    -0.171518
# 118                          co-applicant_race-1_Asian     0.169724
# 99            applicant_ethnicity-1_Hispanic or Latino     0.154446
# 106        applicant_ethnicity_observed_Not applicable    -0.151002
# 120  co-applicant_race-1_Information not provided b...    -0.100055
# 111  applicant_race-1_American Indian or Alaska Native    -0.064000
# 22                             derived_ethnicity_Joint     0.058037
# 117  co-applicant_race-1_American Indian or Alaska ...    -0.054708
# 112                             applicant_race-1_Asian    -0.053643
# 25                                  derived_race_Asian    -0.051163
# 27                                  derived_race_Joint    -0.048878
# 26              derived_race_Black or African American    -0.046572
# ...

# %% [markdown]
# ## 2020

# %%
coefficient_sorted_2020 = deletezero_sort(coefficient_df_2020)
coefficient_sorted_2020
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature   Coefficient  \
# ...

# %%
coefficient_imp_2020 = filter_features_by_prefix(coefficient_df_2020)
coefficient_imp_2020
# Out:
#                                                Feature   Coefficient  \
# 124             applicant_race_observed_Not applicable -3.927088e-01
# 21                derived_ethnicity_Hispanic or Latino  2.620162e-01
# 115  applicant_race-1_Information not provided by a... -2.083749e-01
# 29                     derived_race_Race Not Available -2.083385e-01
# 107        applicant_ethnicity_observed_Not applicable -1.773947e-01
# 108  applicant_ethnicity_observed_Not collected on ... -1.256098e-01
# 103        co-applicant_ethnicity-1_Hispanic or Latino  1.069788e-01
# 27                                  derived_race_Joint -9.997374e-02
# 101  applicant_ethnicity-1_Information not provided...  9.765991e-02
# 20           derived_ethnicity_Ethnicity Not Available  9.722106e-02
# 100           applicant_ethnicity-1_Hispanic or Latino  7.520104e-02
# 111  co-applicant_ethnicity_observed_Not collected ...  6.053078e-02
# 119                          co-applicant_race-1_Asian -5.646334e-02
# ...

# %% [markdown]
# ## 2021

# %%
coefficient_sorted_2021 = deletezero_sort(coefficient_df_2021)
coefficient_sorted_2021
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.075107
# ...

# %%
coefficient_imp_2021 = filter_features_by_prefix(coefficient_df_2021)
coefficient_imp_2021
# Out:
#                                                Feature  Coefficient  \
# 22                             derived_ethnicity_Joint     0.135085
# 127  co-applicant_race_observed_Not collected on th...     0.107237
# 100           applicant_ethnicity-1_Hispanic or Latino    -0.104972
# 126          co-applicant_race_observed_Not applicable    -0.100327
# 106        applicant_ethnicity_observed_Not applicable    -0.090431
# 123             applicant_race_observed_Not applicable    -0.089167
# 118                          co-applicant_race-1_Asian    -0.083836
# 23               derived_race_2 or more minority races     0.068735
# 21                derived_ethnicity_Hispanic or Latino    -0.068065
# 25                                  derived_race_Asian     0.066700
# 113         applicant_race-1_Black or African American     0.063655
# 101  applicant_ethnicity-1_Information not provided...    -0.052076
# 20           derived_ethnicity_Ethnicity Not Available    -0.051351
# ...

# %% [markdown]
# ## 2022

# %%
coefficient_sorted_2022 = deletezero_sort(coefficient_df_2022)
coefficient_sorted_2022
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_91328/2794036433.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['odds_ratio'] = np.exp(df['Coefficient'])
#                                                Feature  Coefficient  \
# 0                                                const     4.422911
# ...

# %%
coefficient_imp_2022 = filter_features_by_prefix(coefficient_df_2022)
coefficient_imp_2022
# Out:
#                                                Feature  Coefficient  \
# 21                derived_ethnicity_Hispanic or Latino    -0.175504
# 100           applicant_ethnicity-1_Hispanic or Latino    -0.164934
# 25                                  derived_race_Asian     0.148164
# 113                             applicant_race-1_Asian     0.141871
# 107        applicant_ethnicity_observed_Not applicable    -0.094287
# 125             applicant_race_observed_Not applicable    -0.092189
# 27                                  derived_race_Joint    -0.088956
# 101  applicant_ethnicity-1_Information not provided...    -0.080068
# 20           derived_ethnicity_Ethnicity Not Available    -0.080068
# 26              derived_race_Black or African American    -0.075621
# 22                             derived_ethnicity_Joint    -0.072876
# 103        co-applicant_ethnicity-1_Hispanic or Latino     0.067947
# 121  co-applicant_race-1_Information not provided b...     0.053661
# ...

# %%
len(coefficient_sorted_2018), len(coefficient_sorted_2019), len(coefficient_sorted_2020), len(coefficient_sorted_2021), len(coefficient_sorted_2022)
# Out:
# (80, 130, 119, 127, 162)
