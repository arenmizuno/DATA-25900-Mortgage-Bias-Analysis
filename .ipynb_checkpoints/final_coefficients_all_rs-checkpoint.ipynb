# %%
# imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, LogisticRegression, LassoCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, 
    mean_squared_error, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report, 
    roc_curve, 
    roc_auc_score
)
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# load all coefficient dfs
coefficient_df_2018 = pd.read_csv('coefficient_df_2018_all_rs.csv')
coefficient_df_2019 = pd.read_csv('coefficient_df_2019_all_rs.csv')
coefficient_df_2020 = pd.read_csv('coefficient_df_2020_all_rs.csv')
coefficient_df_2021 = pd.read_csv('coefficient_df_2021_all_rs.csv')
coefficient_df_2022 = pd.read_csv('coefficient_df_2022_all_rs.csv')

# %%
# function that deletes all of the zero coefficients and sorts it
def deletezero_sort(df):
    df = df[df['Coefficient'] != 0]
    df['abs_coefficient'] = df['Coefficient'].abs()
    df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
    df = df.sort_values(by='abs_coefficient', ascending=False)
    return df

# %%
# function that only keeps race, sex, and ethnicity features and sorts it
def filter_features_by_prefix(df):
    prefixes = ['derived_ethnicity', 'derived_race', 'applicant_ethnicity', 'co-applicant_ethnicity', 'applicant_race', 'co-applicant_race']
    filtered_coefficients = pd.DataFrame()
    for prefix in prefixes:
        filtered_coefficients = pd.concat([filtered_coefficients, df[df['Feature'].str.startswith(prefix)]])
    filtered_coefficients['abs_coefficient'] = filtered_coefficients['Coefficient'].abs()
    filtered_coefficients['pct_increase/decrease'] = (np.exp(filtered_coefficients['Coefficient'])-1)*100
    filtered_coefficients = filtered_coefficients.sort_values(by='abs_coefficient', ascending=False)
    return filtered_coefficients

# %% [markdown]
# ## 2018

# %%
coefficient_sorted_2018 = deletezero_sort(coefficient_df_2018)
coefficient_sorted_2018
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                               Feature   Coefficient  \
# 3                                       interest_rate  2.742323e-01
# 18           derived_loan_product_type_FHA:First Lien  2.069208e-01
# 2                                 loan_to_value_ratio  1.687868e-01
# 1                                         loan_amount -1.102904e-01
# 20            derived_loan_product_type_VA:First Lien -8.327119e-02
# ..                                                ...           ...
# 25              derived_race_2 or more minority races -9.686835e-06
# 58                     construction_method_Site-built -1.183081e-06
# 49          lien_status_Secured by a subordinate lien  1.371240e-08
# 59  manufactured_home_secured_property_type_Not ap... -6.842409e-17
# 60  manufactured_home_land_property_interest_Not a... -2.787212e-18
#
#     abs_coefficient  pct_increase/decrease
# 3      2.742323e-01           3.155204e+01
# 18     2.069208e-01           2.298852e+01
# 2      1.687868e-01           1.838678e+01
# 1      1.102904e-01          -1.044260e+01
# 20     8.327119e-02          -7.989841e+00
# ..              ...                    ...
# 25     9.686835e-06          -9.686788e-04
# 58     1.183081e-06          -1.183081e-04
# 49     1.371240e-08           1.371240e-06
# 59     6.842409e-17          -1.110223e-14
# 60     2.787212e-18           0.000000e+00
#
# [137 rows x 4 columns]

# %%
coefficient_imp_2018 = filter_features_by_prefix(coefficient_df_2018)
coefficient_imp_2018
# Out:
#                                                Feature  Coefficient  \
# 107  applicant_ethnicity_observed_Not collected on ...     0.019567
# 124             applicant_race_observed_Not applicable     0.012840
# 28              derived_race_Black or African American     0.009421
# 23                derived_ethnicity_Hispanic or Latino     0.008334
# 125  applicant_race_observed_Not collected on the b...     0.007448
# 112                             applicant_race-1_Asian     0.005784
# 27                                  derived_race_Asian    -0.005677
# 118                          co-applicant_race-1_Asian     0.004853
# 113         applicant_race-1_Black or African American     0.003953
# 103  co-applicant_ethnicity-1_Information not provi...    -0.003041
# 116                    applicant_race-1_Not applicable    -0.002509
# 119      co-applicant_race-1_Black or African American     0.002449
# 31                     derived_race_Race Not Available    -0.002407
# 128  co-applicant_race_observed_Not collected on th...    -0.001406
# 127          co-applicant_race_observed_Not applicable    -0.001358
# 105            co-applicant_ethnicity-1_Not applicable    -0.001235
# 121  co-applicant_race-1_Native Hawaiian or Other P...     0.001086
# 26       derived_race_American Indian or Alaska Native     0.001049
# 24                             derived_ethnicity_Joint     0.001017
# 102        co-applicant_ethnicity-1_Hispanic or Latino     0.000862
# 123                 co-applicant_race-1_Not applicable     0.000602
# 30   derived_race_Native Hawaiian or Other Pacific ...     0.000235
# 117  co-applicant_race-1_American Indian or Alaska ...     0.000077
# 115  applicant_race-1_Native Hawaiian or Other Paci...     0.000015
# 25               derived_race_2 or more minority races    -0.000010
# 126         co-applicant_race_observed_No co-applicant     0.000000
# 120  co-applicant_race-1_Information not provided b...    -0.000000
# 122                co-applicant_race-1_No co-applicant     0.000000
# 22           derived_ethnicity_Ethnicity Not Available    -0.000000
# 114  applicant_race-1_Information not provided by a...    -0.000000
# 111  applicant_race-1_American Indian or Alaska Native     0.000000
# 110  co-applicant_ethnicity_observed_Not collected ...     0.000000
# 108    co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 104           co-applicant_ethnicity-1_No co-applicant    -0.000000
# 106        applicant_ethnicity_observed_Not applicable     0.000000
# 101               applicant_ethnicity-1_Not applicable    -0.000000
# 100  applicant_ethnicity-1_Information not provided...    -0.000000
# 99            applicant_ethnicity-1_Hispanic or Latino     0.000000
# 29                                  derived_race_Joint    -0.000000
# 109     co-applicant_ethnicity_observed_Not applicable    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 107         0.019567               1.975936
# 124         0.012840               1.292327
# 28          0.009421               0.946512
# 23          0.008334               0.836915
# 125         0.007448               0.747561
# 112         0.005784               0.580092
# 27          0.005677              -0.566042
# 118         0.004853               0.486466
# 113         0.003953               0.396109
# 103         0.003041              -0.303632
# 116         0.002509              -0.250600
# 119         0.002449               0.245181
# 31          0.002407              -0.240444
# 128         0.001406              -0.140467
# 127         0.001358              -0.135682
# 105         0.001235              -0.123443
# 121         0.001086               0.108662
# 26          0.001049               0.104938
# 24          0.001017               0.101753
# 102         0.000862               0.086216
# 123         0.000602               0.060197
# 30          0.000235               0.023531
# 117         0.000077               0.007697
# 115         0.000015               0.001507
# 25          0.000010              -0.000969
# 126         0.000000               0.000000
# 120         0.000000               0.000000
# 122         0.000000               0.000000
# 22          0.000000               0.000000
# 114         0.000000               0.000000
# 111         0.000000               0.000000
# 110         0.000000               0.000000
# 108         0.000000               0.000000
# 104         0.000000               0.000000
# 106         0.000000               0.000000
# 101         0.000000               0.000000
# 100         0.000000               0.000000
# 99          0.000000               0.000000
# 29          0.000000               0.000000
# 109         0.000000               0.000000

# %% [markdown]
# ## 2019

# %%
coefficient_sorted_2019 = deletezero_sort(coefficient_df_2019)
coefficient_sorted_2019
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature   Coefficient  \
# 3                                        interest_rate  2.889367e-01
# 18            derived_loan_product_type_FHA:First Lien  2.300443e-01
# 2                                  loan_to_value_ratio  1.472124e-01
# 1                                          loan_amount -1.017850e-01
# 20             derived_loan_product_type_VA:First Lien -7.077481e-02
# ..                                                 ...           ...
# 154                         applicant_age_above_62_Yes  2.933058e-05
# 57                      construction_method_Site-built -1.882532e-06
# 124         co-applicant_race_observed_No co-applicant  1.088512e-06
# 58   manufactured_home_secured_property_type_Not ap... -9.226441e-17
# 59   manufactured_home_land_property_interest_Not a... -1.275943e-17
#
#      abs_coefficient  pct_increase/decrease
# 3       2.889367e-01           3.350073e+01
# 18      2.300443e-01           2.586558e+01
# 2       1.472124e-01           1.586000e+01
# 1       1.017850e-01          -9.677625e+00
# 20      7.077481e-02          -6.832832e+00
# ..               ...                    ...
# 154     2.933058e-05           2.933101e-03
# 57      1.882532e-06          -1.882530e-04
# 124     1.088512e-06           1.088513e-04
# 58      9.226441e-17          -1.110223e-14
# 59      1.275943e-17           0.000000e+00
#
# [143 rows x 4 columns]

# %%
coefficient_imp_2019 = filter_features_by_prefix(coefficient_df_2019)
coefficient_imp_2019
# Out:
#                                                Feature  Coefficient  \
# 122             applicant_race_observed_Not applicable    -0.031537
# 121                co-applicant_race-1_No co-applicant     0.025725
# 112         applicant_race-1_Black or African American     0.017084
# 105        applicant_ethnicity_observed_Not applicable     0.015347
# 125          co-applicant_race_observed_Not applicable     0.011350
# 98            applicant_ethnicity-1_Hispanic or Latino     0.009991
# 23                derived_ethnicity_Hispanic or Latino     0.008485
# 102  co-applicant_ethnicity-1_Information not provi...     0.008279
# 101        co-applicant_ethnicity-1_Hispanic or Latino     0.007377
# 26       derived_race_American Indian or Alaska Native    -0.006823
# 99   applicant_ethnicity-1_Information not provided...     0.006168
# 115                    applicant_race-1_Not applicable    -0.005593
# 123  applicant_race_observed_Not collected on the b...     0.005360
# 126  co-applicant_race_observed_Not collected on th...    -0.005328
# 117                          co-applicant_race-1_Asian     0.005269
# 110  applicant_race-1_American Indian or Alaska Native     0.004243
# 119  co-applicant_race-1_Information not provided b...    -0.003593
# 106  applicant_ethnicity_observed_Not collected on ...     0.003436
# 118      co-applicant_race-1_Black or African American     0.002714
# 114  applicant_race-1_Native Hawaiian or Other Paci...     0.002516
# 30   derived_race_Native Hawaiian or Other Pacific ...    -0.002356
# 29                                  derived_race_Joint    -0.002314
# 108     co-applicant_ethnicity_observed_Not applicable     0.001925
# 22           derived_ethnicity_Ethnicity Not Available     0.001778
# 27                                  derived_race_Asian    -0.001437
# 31                     derived_race_Race Not Available    -0.000961
# 120  co-applicant_race-1_Native Hawaiian or Other P...    -0.000576
# 25               derived_race_2 or more minority races     0.000402
# 104            co-applicant_ethnicity-1_Not applicable     0.000338
# 100               applicant_ethnicity-1_Not applicable     0.000194
# 24                             derived_ethnicity_Joint     0.000047
# 124         co-applicant_race_observed_No co-applicant     0.000001
# 111                             applicant_race-1_Asian    -0.000000
# 113  applicant_race-1_Information not provided by a...    -0.000000
# 109  co-applicant_ethnicity_observed_Not collected ...    -0.000000
# 103           co-applicant_ethnicity-1_No co-applicant     0.000000
# 116  co-applicant_race-1_American Indian or Alaska ...     0.000000
# 28              derived_race_Black or African American    -0.000000
# 107    co-applicant_ethnicity_observed_No co-applicant     0.000000
#
#      abs_coefficient  pct_increase/decrease
# 122         0.031537              -3.104462
# 121         0.025725               2.605897
# 112         0.017084               1.723029
# 105         0.015347               1.546518
# 125         0.011350               1.141492
# 98          0.009991               1.004073
# 23          0.008485               0.852064
# 102         0.008279               0.831383
# 101         0.007377               0.740464
# 26          0.006823              -0.680020
# 99          0.006168               0.618735
# 115         0.005593              -0.557698
# 123         0.005360               0.537426
# 126         0.005328              -0.531339
# 117         0.005269               0.528317
# 110         0.004243               0.425205
# 119         0.003593              -0.358667
# 106         0.003436               0.344171
# 118         0.002714               0.271749
# 114         0.002516               0.251947
# 30          0.002356              -0.235311
# 29          0.002314              -0.231169
# 108         0.001925               0.192728
# 22          0.001778               0.177944
# 27          0.001437              -0.143635
# 31          0.000961              -0.096079
# 120         0.000576              -0.057628
# 25          0.000402               0.040186
# 104         0.000338               0.033845
# 100         0.000194               0.019433
# 24          0.000047               0.004700
# 124         0.000001               0.000109
# 111         0.000000               0.000000
# 113         0.000000               0.000000
# 109         0.000000               0.000000
# 103         0.000000               0.000000
# 116         0.000000               0.000000
# 28          0.000000               0.000000
# 107         0.000000               0.000000

# %% [markdown]
# ## 2020

# %%
coefficient_sorted_2020 = deletezero_sort(coefficient_df_2020)
coefficient_sorted_2020
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature  Coefficient  \
# 3                                        interest_rate     0.232114
# 18            derived_loan_product_type_FHA:First Lien     0.216112
# 2                                  loan_to_value_ratio     0.128654
# 1                                          loan_amount    -0.114149
# 20             derived_loan_product_type_VA:First Lien    -0.064855
# ..                                                 ...          ...
# 128  applicant_sex_Information not provided by appl...    -0.000131
# 126  applicant_sex_Applicant selected both male and...    -0.000107
# 114                    applicant_race-1_Not applicable    -0.000068
# 84   applicant_credit_score_type_More than one cred...    -0.000063
# 46   loan_type_USDA Rural Housing Service or Farm S...     0.000055
#
#      abs_coefficient  pct_increase/decrease
# 3           0.232114              26.126329
# 18          0.216112              24.124201
# 2           0.128654              13.729665
# 1           0.114149             -10.787480
# 20          0.064855              -6.279652
# ..               ...                    ...
# 128         0.000131              -0.013082
# 126         0.000107              -0.010664
# 114         0.000068              -0.006770
# 84          0.000063              -0.006329
# 46          0.000055               0.005465
#
# [129 rows x 4 columns]

# %%
coefficient_imp_2020 = filter_features_by_prefix(coefficient_df_2020)
coefficient_imp_2020
# Out:
#                                                Feature  Coefficient  \
# 104        applicant_ethnicity_observed_Not applicable     0.018563
# 98            applicant_ethnicity-1_Hispanic or Latino     0.016463
# 108  co-applicant_ethnicity_observed_Not collected ...     0.014303
# 28              derived_race_Black or African American     0.009909
# 111         applicant_race-1_Black or African American     0.008902
# 100        co-applicant_ethnicity-1_Hispanic or Latino     0.007642
# 27                                  derived_race_Asian     0.007111
# 110                             applicant_race-1_Asian    -0.006988
# 116                          co-applicant_race-1_Asian     0.004398
# 101  co-applicant_ethnicity-1_Information not provi...    -0.003977
# 117      co-applicant_race-1_Black or African American     0.003667
# 31                     derived_race_Race Not Available     0.003506
# 99   applicant_ethnicity-1_Information not provided...     0.003147
# 103            co-applicant_ethnicity-1_Not applicable     0.002500
# 122  applicant_race_observed_Not collected on the b...     0.001921
# 22           derived_ethnicity_Ethnicity Not Available     0.001916
# 118  co-applicant_race-1_Information not provided b...     0.001853
# 25               derived_race_2 or more minority races     0.001768
# 112  applicant_race-1_Information not provided by a...     0.001453
# 24                             derived_ethnicity_Joint    -0.001435
# 105  applicant_ethnicity_observed_Not collected on ...     0.001069
# 113  applicant_race-1_Native Hawaiian or Other Paci...     0.001008
# 115  co-applicant_race-1_American Indian or Alaska ...    -0.000918
# 119  co-applicant_race-1_Native Hawaiian or Other P...    -0.000759
# 107     co-applicant_ethnicity_observed_Not applicable    -0.000706
# 109  applicant_race-1_American Indian or Alaska Native     0.000450
# 29                                  derived_race_Joint    -0.000322
# 114                    applicant_race-1_Not applicable    -0.000068
# 121             applicant_race_observed_Not applicable     0.000000
# 23                derived_ethnicity_Hispanic or Latino    -0.000000
# 106    co-applicant_ethnicity_observed_No co-applicant     0.000000
# 102           co-applicant_ethnicity-1_No co-applicant     0.000000
# 30   derived_race_Native Hawaiian or Other Pacific ...    -0.000000
# 26       derived_race_American Indian or Alaska Native    -0.000000
# 120                co-applicant_race-1_No co-applicant     0.000000
# 123         co-applicant_race_observed_No co-applicant     0.000000
# 124          co-applicant_race_observed_Not applicable    -0.000000
# 125  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  pct_increase/decrease
# 104         0.018563               1.873642
# 98          0.016463               1.659969
# 108         0.014303               1.440576
# 28          0.009909               0.995843
# 111         0.008902               0.894162
# 100         0.007642               0.767150
# 27          0.007111               0.713678
# 110         0.006988              -0.696371
# 116         0.004398               0.440800
# 101         0.003977              -0.396868
# 117         0.003667               0.367329
# 31          0.003506               0.351215
# 99          0.003147               0.315151
# 103         0.002500               0.250276
# 122         0.001921               0.192313
# 22          0.001916               0.191819
# 118         0.001853               0.185518
# 25          0.001768               0.176910
# 112         0.001453               0.145396
# 24          0.001435              -0.143445
# 105         0.001069               0.107004
# 113         0.001008               0.100821
# 115         0.000918              -0.091805
# 119         0.000759              -0.075893
# 107         0.000706              -0.070622
# 109         0.000450               0.045012
# 29          0.000322              -0.032234
# 114         0.000068              -0.006770
# 121         0.000000               0.000000
# 23          0.000000               0.000000
# 106         0.000000               0.000000
# 102         0.000000               0.000000
# 30          0.000000               0.000000
# 26          0.000000               0.000000
# 120         0.000000               0.000000
# 123         0.000000               0.000000
# 124         0.000000               0.000000
# 125         0.000000               0.000000

# %% [markdown]
# ## 2021

# %%
coefficient_sorted_2021 = deletezero_sort(coefficient_df_2021)
coefficient_sorted_2021
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature   Coefficient  \
# 3                                        interest_rate  2.496821e-01
# 18            derived_loan_product_type_FHA:First Lien  2.303566e-01
# 1                                          loan_amount -1.401892e-01
# 2                                  loan_to_value_ratio  1.190893e-01
# 7                                       property_value  6.375474e-02
# ..                                                 ...           ...
# 17   derived_loan_product_type_Conventional:Subordi...  1.539846e-05
# 100               applicant_ethnicity-1_Not applicable -1.268414e-05
# 10                   tract_minority_population_percent  7.282301e-06
# 46   loan_type_USDA Rural Housing Service or Farm S...  5.134473e-07
# 58   manufactured_home_secured_property_type_Not ap... -4.167476e-18
#
#      abs_coefficient  pct_increase/decrease
# 3       2.496821e-01              28.361733
# 18      2.303566e-01              25.904894
# 1       1.401892e-01             -13.080625
# 2       1.190893e-01              12.647056
# 7       6.375474e-02               6.583096
# ..               ...                    ...
# 17      1.539846e-05               0.001540
# 100     1.268414e-05              -0.001268
# 10      7.282301e-06               0.000728
# 46      5.134473e-07               0.000051
# 58      4.167476e-18               0.000000
#
# [136 rows x 4 columns]

# %%
coefficient_imp_2021 = filter_features_by_prefix(coefficient_df_2021)
coefficient_imp_2021
# Out:
#                                                Feature  Coefficient  \
# 111         applicant_race-1_Black or African American     0.009967
# 98            applicant_ethnicity-1_Hispanic or Latino     0.005358
# 108  co-applicant_ethnicity_observed_Not collected ...     0.004624
# 101        co-applicant_ethnicity-1_Hispanic or Latino     0.003130
# 116      co-applicant_race-1_Black or African American     0.002836
# 124  co-applicant_race_observed_Not collected on th...     0.002802
# 22           derived_ethnicity_Ethnicity Not Available     0.002792
# 105  applicant_ethnicity_observed_Not collected on ...    -0.002080
# 24                             derived_ethnicity_Joint    -0.001998
# 117  co-applicant_race-1_Information not provided b...     0.001880
# 110                             applicant_race-1_Asian    -0.001759
# 99   applicant_ethnicity-1_Information not provided...     0.001527
# 28              derived_race_Black or African American     0.001461
# 115                          co-applicant_race-1_Asian     0.001203
# 102  co-applicant_ethnicity-1_Information not provi...    -0.000772
# 25               derived_race_2 or more minority races     0.000753
# 23                derived_ethnicity_Hispanic or Latino     0.000753
# 112  applicant_race-1_Information not provided by a...    -0.000648
# 31                     derived_race_Race Not Available    -0.000519
# 30   derived_race_Native Hawaiian or Other Pacific ...     0.000459
# 109  applicant_race-1_American Indian or Alaska Native     0.000358
# 114  co-applicant_race-1_American Indian or Alaska ...    -0.000353
# 29                                  derived_race_Joint     0.000316
# 113  applicant_race-1_Native Hawaiian or Other Paci...     0.000266
# 120             applicant_race_observed_Not applicable    -0.000265
# 118  co-applicant_race-1_Native Hawaiian or Other P...     0.000264
# 26       derived_race_American Indian or Alaska Native    -0.000147
# 100               applicant_ethnicity-1_Not applicable    -0.000013
# 107     co-applicant_ethnicity_observed_Not applicable     0.000000
# 121  applicant_race_observed_Not collected on the b...     0.000000
# 103           co-applicant_ethnicity-1_No co-applicant    -0.000000
# 27                                  derived_race_Asian     0.000000
# 104        applicant_ethnicity_observed_Not applicable    -0.000000
# 119                co-applicant_race-1_No co-applicant    -0.000000
# 122         co-applicant_race_observed_No co-applicant    -0.000000
# 123          co-applicant_race_observed_Not applicable     0.000000
# 106    co-applicant_ethnicity_observed_No co-applicant    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 111         0.009967               1.001697
# 98          0.005358               0.537221
# 108         0.004624               0.463434
# 101         0.003130               0.313448
# 116         0.002836               0.283973
# 124         0.002802               0.280619
# 22          0.002792               0.279623
# 105         0.002080              -0.207788
# 24          0.001998              -0.199585
# 117         0.001880               0.188221
# 110         0.001759              -0.175776
# 99          0.001527               0.152834
# 28          0.001461               0.146205
# 115         0.001203               0.120388
# 102         0.000772              -0.077219
# 25          0.000753               0.075377
# 23          0.000753               0.075301
# 112         0.000648              -0.064792
# 31          0.000519              -0.051844
# 30          0.000459               0.045904
# 109         0.000358               0.035846
# 114         0.000353              -0.035318
# 29          0.000316               0.031594
# 113         0.000266               0.026605
# 120         0.000265              -0.026503
# 118         0.000264               0.026415
# 26          0.000147              -0.014672
# 100         0.000013              -0.001268
# 107         0.000000               0.000000
# 121         0.000000               0.000000
# 103         0.000000               0.000000
# 27          0.000000               0.000000
# 104         0.000000               0.000000
# 119         0.000000               0.000000
# 122         0.000000               0.000000
# 123         0.000000               0.000000
# 106         0.000000               0.000000

# %% [markdown]
# ## 2022

# %%
coefficient_sorted_2022 = deletezero_sort(coefficient_df_2022)
coefficient_sorted_2022
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92346/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                              Feature  Coefficient  \
# 18          derived_loan_product_type_FHA:First Lien     0.187492
# 1                                        loan_amount    -0.185583
# 2                                loan_to_value_ratio     0.150786
# 21           derived_loan_product_type_VA:First Lien    -0.110877
# 3                                      interest_rate     0.097392
# ..                                               ...          ...
# 62                                     total_units_3     0.000290
# 20      derived_loan_product_type_FSA/RHS:First Lien    -0.000166
# 100  co-applicant_credit_score_type_VantageScore 3.0     0.000159
# 63                                     total_units_4    -0.000141
# 56                balloon_payment_No balloon payment    -0.000115
#
#      abs_coefficient  pct_increase/decrease
# 18          0.187492              20.622004
# 1           0.185583             -16.938035
# 2           0.150786              16.274767
# 21          0.110877             -10.495147
# 3           0.097392              10.229259
# ..               ...                    ...
# 62          0.000290               0.028962
# 20          0.000166              -0.016596
# 100         0.000159               0.015941
# 63          0.000141              -0.014135
# 56          0.000115              -0.011458
#
# [133 rows x 4 columns]

# %%
coefficient_imp_2022 = filter_features_by_prefix(coefficient_df_2022)
coefficient_imp_2022
# Out:
#                                                Feature  Coefficient  \
# 109  applicant_ethnicity_observed_Not collected on ...    -0.024631
# 126  applicant_race_observed_Not collected on the b...    -0.019061
# 28                                  derived_race_Asian    -0.017142
# 24                derived_ethnicity_Hispanic or Latino    -0.013736
# 104        co-applicant_ethnicity-1_Hispanic or Latino     0.012491
# 115         applicant_race-1_Black or African American     0.011492
# 117  applicant_race-1_Native Hawaiian or Other Paci...    -0.007850
# 101           applicant_ethnicity-1_Hispanic or Latino     0.007465
# 31   derived_race_Native Hawaiian or Other Pacific ...     0.006519
# 107            co-applicant_ethnicity-1_Not applicable     0.004503
# 120      co-applicant_race-1_Black or African American     0.003865
# 121  co-applicant_race-1_Information not provided b...    -0.003562
# 26               derived_race_2 or more minority races     0.003296
# 103               applicant_ethnicity-1_Not applicable    -0.002967
# 32                     derived_race_Race Not Available     0.002739
# 105  co-applicant_ethnicity-1_Information not provi...     0.002463
# 29              derived_race_Black or African American     0.002459
# 102  applicant_ethnicity-1_Information not provided...     0.002282
# 23           derived_ethnicity_Ethnicity Not Available     0.001616
# 114                             applicant_race-1_Asian    -0.001110
# 118  co-applicant_race-1_American Indian or Alaska ...     0.000799
# 119                          co-applicant_race-1_Asian     0.000780
# 30                                  derived_race_Joint    -0.000532
# 113  applicant_race-1_American Indian or Alaska Native    -0.000360
# 124                 co-applicant_race-1_Not applicable     0.000327
# 123                co-applicant_race-1_No co-applicant    -0.000000
# 122  co-applicant_race-1_Native Hawaiian or Other P...     0.000000
# 127         co-applicant_race_observed_No co-applicant    -0.000000
# 128          co-applicant_race_observed_Not applicable     0.000000
# 110    co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 125             applicant_race_observed_Not applicable    -0.000000
# 116  applicant_race-1_Information not provided by a...     0.000000
# 112  co-applicant_ethnicity_observed_Not collected ...    -0.000000
# 111     co-applicant_ethnicity_observed_Not applicable    -0.000000
# 106           co-applicant_ethnicity-1_No co-applicant    -0.000000
# 108        applicant_ethnicity_observed_Not applicable    -0.000000
# 27       derived_race_American Indian or Alaska Native     0.000000
# 25                             derived_ethnicity_Joint    -0.000000
# 129  co-applicant_race_observed_Not collected on th...    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 109         0.024631              -2.433026
# 126         0.019061              -1.888008
# 28          0.017142              -1.699598
# 24          0.013736              -1.364181
# 104         0.012491               1.256954
# 115         0.011492               1.155805
# 117         0.007850              -0.781911
# 101         0.007465               0.749254
# 31          0.006519               0.654068
# 107         0.004503               0.451357
# 120         0.003865               0.387214
# 121         0.003562              -0.355540
# 26          0.003296               0.330156
# 103         0.002967              -0.296286
# 32          0.002739               0.274301
# 105         0.002463               0.246591
# 29          0.002459               0.246229
# 102         0.002282               0.228487
# 23          0.001616               0.161755
# 114         0.001110              -0.110942
# 118         0.000799               0.079887
# 119         0.000780               0.077989
# 30          0.000532              -0.053157
# 113         0.000360              -0.036015
# 124         0.000327               0.032681
# 123         0.000000               0.000000
# 122         0.000000               0.000000
# 127         0.000000               0.000000
# 128         0.000000               0.000000
# 110         0.000000               0.000000
# 125         0.000000               0.000000
# 116         0.000000               0.000000
# 112         0.000000               0.000000
# 111         0.000000               0.000000
# 106         0.000000               0.000000
# 108         0.000000               0.000000
# 27          0.000000               0.000000
# 25          0.000000               0.000000
# 129         0.000000               0.000000
