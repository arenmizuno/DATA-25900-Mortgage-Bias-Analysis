# %%
# imports
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, LogisticRegression, LassoCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, 
    mean_squared_error, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report, 
    roc_curve, 
    roc_auc_score
)
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# load all coefficient dfs
coefficient_df_2018 = pd.read_csv('coefficient_df_2018_derived_rs.csv')
coefficient_df_2019 = pd.read_csv('coefficient_df_2019_derived_rs.csv')
coefficient_df_2020 = pd.read_csv('coefficient_df_2020_derived_rs.csv')
coefficient_df_2021 = pd.read_csv('coefficient_df_2021_derived_rs.csv')
coefficient_df_2022 = pd.read_csv('coefficient_df_2022_derived_rs.csv')

# %%
# function that deletes all of the zero coefficients and sorts it
def deletezero_sort(df):
    df = df[df['Coefficient'] != 0]
    df['abs_coefficient'] = df['Coefficient'].abs()
    df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
    df = df.sort_values(by='abs_coefficient', ascending=False)
    return df

# %%
# function that only keeps race, sex, and ethnicity features and sorts it
def filter_features_by_prefix(df):
    prefixes = ['derived_ethnicity', 'derived_race', 'applicant_ethnicity', 'co-applicant_ethnicity', 'applicant_race', 'co-applicant_race']
    filtered_coefficients = pd.DataFrame()
    for prefix in prefixes:
        filtered_coefficients = pd.concat([filtered_coefficients, df[df['Feature'].str.startswith(prefix)]])
    filtered_coefficients['abs_coefficient'] = filtered_coefficients['Coefficient'].abs()
    filtered_coefficients['pct_increase/decrease'] = (np.exp(filtered_coefficients['Coefficient'])-1)*100
    filtered_coefficients = filtered_coefficients.sort_values(by='abs_coefficient', ascending=False)
    return filtered_coefficients

# %% [markdown]
# ## 2018

# %%
coefficient_sorted_2018 = deletezero_sort(coefficient_df_2018)
coefficient_sorted_2018
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature  Coefficient  \
# 3                                        interest_rate     0.274275
# 18            derived_loan_product_type_FHA:First Lien     0.207055
# 2                                  loan_to_value_ratio     0.169020
# 1                                          loan_amount    -0.111107
# 20             derived_loan_product_type_VA:First Lien    -0.083376
# 5                                  origination_charges     0.039965
# 118  applicant_sex_observed_Not collected on the ba...    -0.038703
# 4                                     total_loan_costs     0.031267
# 100  applicant_ethnicity_observed_Not collected on ...     0.020154
# 42                       purchaser_type_Not applicable    -0.019032
# 8                                               income     0.018371
# 36   purchaser_type_Credit union, mortgage company,...     0.014958
# 28              derived_race_Black or African American     0.014175
# 104             applicant_race_observed_Not applicable     0.013049
# 94      co-applicant_credit_score_type_No co-applicant    -0.012954
#
#      abs_coefficient  pct_increase/decrease
# 3           0.274275              31.557649
# 18          0.207055              23.005004
# 2           0.169020              18.414406
# 1           0.111107             -10.515743
# 20          0.083376              -7.999527
# 5           0.039965               4.077407
# 118         0.038703              -3.796320
# 4           0.031267               3.176119
# 100         0.020154               2.035811
# 42          0.019032              -1.885247
# 8           0.018371               1.854043
# 36          0.014958               1.507056
# 28          0.014175               1.427566
# 104         0.013049               1.313464
# 94          0.012954              -1.287093

# %%
coefficient_imp_2018 = filter_features_by_prefix(coefficient_df_2018)
coefficient_imp_2018
# Out:
#                                                Feature  Coefficient  \
# 100  applicant_ethnicity_observed_Not collected on ...     0.020154
# 28              derived_race_Black or African American     0.014175
# 104             applicant_race_observed_Not applicable     0.013049
# 23                derived_ethnicity_Hispanic or Latino     0.008576
# 105  applicant_race_observed_Not collected on the b...     0.007923
# 29                                  derived_race_Joint     0.002620
# 31                     derived_race_Race Not Available    -0.002573
# 108  co-applicant_race_observed_Not collected on th...    -0.002420
# 27                                  derived_race_Asian     0.001937
# 102     co-applicant_ethnicity_observed_Not applicable    -0.001830
# 24                             derived_ethnicity_Joint     0.001164
# 22           derived_ethnicity_Ethnicity Not Available    -0.001140
# 26       derived_race_American Indian or Alaska Native     0.001112
# 30   derived_race_Native Hawaiian or Other Pacific ...     0.000605
# 25               derived_race_2 or more minority races     0.000355
# 101    co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 103  co-applicant_ethnicity_observed_Not collected ...     0.000000
# 106         co-applicant_race_observed_No co-applicant     0.000000
# 107          co-applicant_race_observed_Not applicable    -0.000000
# 99         applicant_ethnicity_observed_Not applicable     0.000000
#
#      abs_coefficient  pct_increase/decrease
# 100         0.020154               2.035811
# 28          0.014175               1.427566
# 104         0.013049               1.313464
# 23          0.008576               0.861290
# 105         0.007923               0.795471
# 29          0.002620               0.262362
# 31          0.002573              -0.257016
# 108         0.002420              -0.241687
# 27          0.001937               0.193839
# 102         0.001830              -0.182849
# 24          0.001164               0.116490
# 22          0.001140              -0.113885
# 26          0.001112               0.111250
# 30          0.000605               0.060520
# 25          0.000355               0.035505
# 101         0.000000               0.000000
# 103         0.000000               0.000000
# 106         0.000000               0.000000
# 107         0.000000               0.000000
# 99          0.000000               0.000000

# %% [markdown]
# ## 2019

# %%
coefficient_sorted_2019 = deletezero_sort(coefficient_df_2019)
coefficient_sorted_2019
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                             Feature  Coefficient  \
# 3                                     interest_rate     0.289099
# 18         derived_loan_product_type_FHA:First Lien     0.230537
# 2                               loan_to_value_ratio     0.146871
# 1                                       loan_amount    -0.100004
# 20          derived_loan_product_type_VA:First Lien    -0.069845
# 5                               origination_charges     0.054302
# 94   co-applicant_credit_score_type_No co-applicant    -0.038894
# 103          applicant_race_observed_Not applicable    -0.038158
# 116           applicant_sex_observed_Not applicable     0.023843
# 23             derived_ethnicity_Hispanic or Latino     0.021188
# 4                                  total_loan_costs     0.020997
# 72                          debt_to_income_ratio_44     0.019582
# 105      co-applicant_race_observed_No co-applicant     0.019188
# 11                ffiec_msa_md_median_family_income     0.018485
# 28           derived_race_Black or African American     0.017756
#
#      abs_coefficient  pct_increase/decrease
# 3           0.289099              33.522418
# 18          0.230537              25.927617
# 2           0.146871              15.820421
# 1           0.100004              -9.516622
# 20          0.069845              -6.746179
# 5           0.054302               5.580299
# 94          0.038894              -3.814720
# 103         0.038158              -3.743905
# 116         0.023843               2.412995
# 23          0.021188               2.141384
# 4           0.020997               2.121881
# 72          0.019582               1.977449
# 105         0.019188               1.937282
# 11          0.018485               1.865708
# 28          0.017756               1.791458

# %%
coefficient_imp_2019 = filter_features_by_prefix(coefficient_df_2019)
coefficient_imp_2019
# Out:
#                                                Feature  Coefficient  \
# 103             applicant_race_observed_Not applicable    -0.038158
# 23                derived_ethnicity_Hispanic or Latino     0.021188
# 105         co-applicant_race_observed_No co-applicant     0.019188
# 28              derived_race_Black or African American     0.017756
# 98         applicant_ethnicity_observed_Not applicable     0.015924
# 106          co-applicant_race_observed_Not applicable     0.011078
# 22           derived_ethnicity_Ethnicity Not Available     0.010772
# 107  co-applicant_race_observed_Not collected on th...    -0.007082
# 104  applicant_race_observed_Not collected on the b...     0.006061
# 101     co-applicant_ethnicity_observed_Not applicable     0.005042
# 26       derived_race_American Indian or Alaska Native    -0.003396
# 99   applicant_ethnicity_observed_Not collected on ...     0.003034
# 24                             derived_ethnicity_Joint     0.002977
# 31                     derived_race_Race Not Available    -0.002372
# 25               derived_race_2 or more minority races     0.001641
# 27                                  derived_race_Asian     0.000865
# 29                                  derived_race_Joint     0.000789
# 30   derived_race_Native Hawaiian or Other Pacific ...    -0.000369
# 100    co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 102  co-applicant_ethnicity_observed_Not collected ...     0.000000
#
#      abs_coefficient  pct_increase/decrease
# 103         0.038158              -3.743905
# 23          0.021188               2.141384
# 105         0.019188               1.937282
# 28          0.017756               1.791458
# 98          0.015924               1.605152
# 106         0.011078               1.113961
# 22          0.010772               1.082976
# 107         0.007082              -0.705740
# 104         0.006061               0.607923
# 101         0.005042               0.505515
# 26          0.003396              -0.339067
# 99          0.003034               0.303814
# 24          0.002977               0.298106
# 31          0.002372              -0.236936
# 25          0.001641               0.164274
# 27          0.000865               0.086492
# 29          0.000789               0.078945
# 30          0.000369              -0.036900
# 100         0.000000               0.000000
# 102         0.000000               0.000000

# %% [markdown]
# ## 2020

# %%
coefficient_sorted_2020 = deletezero_sort(coefficient_df_2020)
coefficient_sorted_2020
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature  Coefficient  \
# 3                                        interest_rate     0.232225
# 18            derived_loan_product_type_FHA:First Lien     0.216752
# 2                                  loan_to_value_ratio     0.128231
# 1                                          loan_amount    -0.111404
# 20             derived_loan_product_type_VA:First Lien    -0.064529
# 5                                  origination_charges     0.043453
# 4                                     total_loan_costs     0.037165
# 7                                       property_value     0.029044
# 41                       purchaser_type_Not applicable     0.022005
# 136  submission_of_application_Submitted directly t...    -0.021969
# 28              derived_race_Black or African American     0.019991
# 23                derived_ethnicity_Hispanic or Latino     0.018909
# 98         applicant_ethnicity_observed_Not applicable     0.018158
# 102  co-applicant_ethnicity_observed_Not collected ...     0.014911
# 72                             debt_to_income_ratio_44     0.014066
#
#      abs_coefficient  pct_increase/decrease
# 3           0.232225              26.140378
# 18          0.216752              24.203549
# 2           0.128231              13.681509
# 1           0.111404             -10.542296
# 20          0.064529              -6.249120
# 5           0.043453               4.441107
# 4           0.037165               3.786377
# 7           0.029044               2.946960
# 41          0.022005               2.224865
# 136         0.021969              -2.172905
# 28          0.019991               2.019173
# 23          0.018909               1.908851
# 98          0.018158               1.832351
# 102         0.014911               1.502283
# 72          0.014066               1.416524

# %%
coefficient_imp_2020 = filter_features_by_prefix(coefficient_df_2020)
coefficient_imp_2020
# Out:
#                                                Feature  Coefficient  \
# 28              derived_race_Black or African American     0.019991
# 23                derived_ethnicity_Hispanic or Latino     0.018909
# 98         applicant_ethnicity_observed_Not applicable     0.018158
# 102  co-applicant_ethnicity_observed_Not collected ...     0.014911
# 31                     derived_race_Race Not Available     0.005463
# 22           derived_ethnicity_Ethnicity Not Available     0.003855
# 24                             derived_ethnicity_Joint     0.003600
# 104  applicant_race_observed_Not collected on the b...     0.002498
# 27                                  derived_race_Asian     0.002423
# 25               derived_race_2 or more minority races     0.001825
# 30   derived_race_Native Hawaiian or Other Pacific ...     0.000663
# 29                                  derived_race_Joint     0.000388
# 26       derived_race_American Indian or Alaska Native     0.000065
# 99   applicant_ethnicity_observed_Not collected on ...     0.000000
# 100    co-applicant_ethnicity_observed_No co-applicant     0.000000
# 101     co-applicant_ethnicity_observed_Not applicable    -0.000000
# 103             applicant_race_observed_Not applicable     0.000000
# 105         co-applicant_race_observed_No co-applicant     0.000000
# 106          co-applicant_race_observed_Not applicable     0.000000
# 107  co-applicant_race_observed_Not collected on th...     0.000000
#
#      abs_coefficient  pct_increase/decrease
# 28          0.019991               2.019173
# 23          0.018909               1.908851
# 98          0.018158               1.832351
# 102         0.014911               1.502283
# 31          0.005463               0.547807
# 22          0.003855               0.386216
# 24          0.003600               0.360684
# 104         0.002498               0.250074
# 27          0.002423               0.242601
# 25          0.001825               0.182635
# 30          0.000663               0.066309
# 29          0.000388               0.038831
# 26          0.000065               0.006536
# 99          0.000000               0.000000
# 100         0.000000               0.000000
# 101         0.000000               0.000000
# 103         0.000000               0.000000
# 105         0.000000               0.000000
# 106         0.000000               0.000000
# 107         0.000000               0.000000

# %% [markdown]
# ## 2021

# %%
coefficient_sorted_2021 = deletezero_sort(coefficient_df_2021)
coefficient_sorted_2021
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature  Coefficient  \
# 3                                        interest_rate     0.249779
# 18            derived_loan_product_type_FHA:First Lien     0.231518
# 1                                          loan_amount    -0.140631
# 2                                  loan_to_value_ratio     0.119295
# 7                                       property_value     0.064197
# 20             derived_loan_product_type_VA:First Lien    -0.043217
# 4                                     total_loan_costs     0.029183
# 41                       purchaser_type_Not applicable    -0.023906
# 5                                  origination_charges     0.018141
# 8                                               income     0.013168
# 11                   ffiec_msa_md_median_family_income     0.012627
# 28              derived_race_Black or African American     0.012314
# 19        derived_loan_product_type_FSA/RHS:First Lien     0.010298
# 136  initially_payable_to_institution_Not initially...     0.010208
# 135  submission_of_application_Submitted directly t...     0.008192
#
#      abs_coefficient  pct_increase/decrease
# 3           0.249779              28.374151
# 18          0.231518              26.051179
# 1           0.140631             -13.119058
# 2           0.119295              12.670227
# 7           0.064197               6.630244
# 20          0.043217              -4.229693
# 4           0.029183               2.961262
# 41          0.023906              -2.362216
# 5           0.018141               1.830675
# 8           0.013168               1.325547
# 11          0.012627               1.270693
# 28          0.012314               1.239041
# 19          0.010298               1.035146
# 136         0.010208               1.026053
# 135         0.008192               0.822585

# %%
coefficient_imp_2021 = filter_features_by_prefix(coefficient_df_2021)
coefficient_imp_2021
# Out:
#                                                Feature  Coefficient  \
# 28              derived_race_Black or African American     0.012314
# 23                derived_ethnicity_Hispanic or Latino     0.007309
# 102  co-applicant_ethnicity_observed_Not collected ...     0.006702
# 22           derived_ethnicity_Ethnicity Not Available     0.004227
# 107  co-applicant_race_observed_Not collected on th...     0.002993
# 99   applicant_ethnicity_observed_Not collected on ...    -0.002405
# 29                                  derived_race_Joint     0.001544
# 25               derived_race_2 or more minority races     0.001139
# 27                                  derived_race_Asian    -0.000986
# 30   derived_race_Native Hawaiian or Other Pacific ...     0.000770
# 103             applicant_race_observed_Not applicable    -0.000660
# 31                     derived_race_Race Not Available    -0.000502
# 24                             derived_ethnicity_Joint    -0.000037
# 26       derived_race_American Indian or Alaska Native     0.000000
# 100    co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 101     co-applicant_ethnicity_observed_Not applicable     0.000000
# 104  applicant_race_observed_Not collected on the b...     0.000000
# 105         co-applicant_race_observed_No co-applicant    -0.000000
# 106          co-applicant_race_observed_Not applicable     0.000000
# 98         applicant_ethnicity_observed_Not applicable    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 28          0.012314               1.239041
# 23          0.007309               0.733533
# 102         0.006702               0.672465
# 22          0.004227               0.423574
# 107         0.002993               0.299766
# 99          0.002405              -0.240189
# 29          0.001544               0.154537
# 25          0.001139               0.113986
# 27          0.000986              -0.098531
# 30          0.000770               0.077026
# 103         0.000660              -0.066018
# 31          0.000502              -0.050166
# 24          0.000037              -0.003660
# 26          0.000000               0.000000
# 100         0.000000               0.000000
# 101         0.000000               0.000000
# 104         0.000000               0.000000
# 105         0.000000               0.000000
# 106         0.000000               0.000000
# 98          0.000000               0.000000

# %% [markdown]
# ## 2022

# %%
coefficient_sorted_2022 = deletezero_sort(coefficient_df_2022)
coefficient_sorted_2022
# Out:
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['abs_coefficient'] = df['Coefficient'].abs()
# /var/folders/b9/kvwg4mzj5kv0208_l9z2ljsc0000gn/T/ipykernel_92308/3318337375.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_increase/decrease'] = (np.exp(df['Coefficient'])-1)*100
#                                                Feature  Coefficient  \
# 18            derived_loan_product_type_FHA:First Lien     0.188313
# 1                                          loan_amount    -0.182269
# 2                                  loan_to_value_ratio     0.150312
# 21             derived_loan_product_type_VA:First Lien    -0.110849
# 3                                        interest_rate     0.097569
# 4                                     total_loan_costs     0.093342
# 42                       purchaser_type_Not applicable    -0.080382
# 7                                       property_value     0.060830
# 140  submission_of_application_Submitted directly t...     0.042650
# 136                              co-applicant_age_9999    -0.041601
# 121  applicant_sex_observed_Not collected on the ba...     0.033709
# 141  initially_payable_to_institution_Not initially...     0.032379
# 143                  aus-1_Internal Proprietary System    -0.029898
# 8                                               income     0.024747
# 102  applicant_ethnicity_observed_Not collected on ...    -0.024152
#
#      abs_coefficient  pct_increase/decrease
# 18          0.188313              20.721126
# 1           0.182269             -16.662267
# 2           0.150312              16.219629
# 21          0.110849             -10.492612
# 3           0.097569              10.248804
# 4           0.093342               9.783697
# 42          0.080382              -7.723607
# 7           0.060830               6.271842
# 140         0.042650               4.357221
# 136         0.041601              -4.074756
# 121         0.033709               3.428348
# 141         0.032379               3.290927
# 143         0.029898              -2.945535
# 8           0.024747               2.505596
# 102         0.024152              -2.386252

# %%
coefficient_imp_2022 = filter_features_by_prefix(coefficient_df_2022)
coefficient_imp_2022
# Out:
#                                                Feature  Coefficient  \
# 102  applicant_ethnicity_observed_Not collected on ...    -0.024152
# 107  applicant_race_observed_Not collected on the b...    -0.019161
# 28                                  derived_race_Asian    -0.017799
# 29              derived_race_Black or African American     0.015168
# 23           derived_ethnicity_Ethnicity Not Available     0.004721
# 25                             derived_ethnicity_Joint     0.004127
# 26               derived_race_2 or more minority races     0.003418
# 32                     derived_race_Race Not Available     0.001470
# 24                derived_ethnicity_Hispanic or Latino    -0.001288
# 31   derived_race_Native Hawaiian or Other Pacific ...     0.000209
# 109          co-applicant_race_observed_Not applicable     0.000025
# 105  co-applicant_ethnicity_observed_Not collected ...    -0.000000
# 108         co-applicant_race_observed_No co-applicant    -0.000000
# 106             applicant_race_observed_Not applicable    -0.000000
# 101        applicant_ethnicity_observed_Not applicable    -0.000000
# 104     co-applicant_ethnicity_observed_Not applicable     0.000000
# 103    co-applicant_ethnicity_observed_No co-applicant    -0.000000
# 30                                  derived_race_Joint     0.000000
# 27       derived_race_American Indian or Alaska Native    -0.000000
# 110  co-applicant_race_observed_Not collected on th...    -0.000000
#
#      abs_coefficient  pct_increase/decrease
# 102         0.024152              -2.386252
# 107         0.019161              -1.897818
# 28          0.017799              -1.764198
# 29          0.015168               1.528317
# 23          0.004721               0.473258
# 25          0.004127               0.413579
# 26          0.003418               0.342433
# 32          0.001470               0.147082
# 24          0.001288              -0.128766
# 31          0.000209               0.020915
# 109         0.000025               0.002461
# 105         0.000000               0.000000
# 108         0.000000               0.000000
# 106         0.000000               0.000000
# 101         0.000000               0.000000
# 104         0.000000               0.000000
# 103         0.000000               0.000000
# 30          0.000000               0.000000
# 27          0.000000               0.000000
# 110         0.000000               0.000000
